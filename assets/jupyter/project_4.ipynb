# %% [markdown]
# # Project 4: Clustering the Future - Leveraging Collegiate and Athletic Data to Find NFL Comparisons for College Players

# %%
import pandas as pd
import numpy as np
import nfl_data_py as nfl
import cfbd
import requests
from bs4 import BeautifulSoup
from time import sleep
from fuzzywuzzy import process
import os
from dotenv import load_dotenv

import requests
from time import sleep
from great_tables import GT, system_fonts, style, loc, md
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# # I. Getting our data & pre-processing

# %%
# Load our environment variables
load_dotenv()
# Out:
# True

# %%
# Set up our college football API
configuration = cfbd.Configuration(
    host = "https://apinext.collegefootballdata.com"
)

# Load environment variables from the .env file
load_dotenv()

configuration = cfbd.Configuration(
    access_token = os.getenv('CFBD')
)

# %%
all_RAS: pd.DataFrame = pd.read_csv('./datasets/RAS Scores.csv')
RAS_2025: pd.DataFrame = pd.read_csv('./datasets/RAS 2025 Draft Class.csv').drop_duplicates(subset=['RAS', 'Name'])
all_RAS
# Out:
#                                                     Link                Name  \
# 0      <a   class="nt_btn " style="color: rgba(0, 0, ...       Justin Fargas
# 1      <a   class="nt_btn " style="color: rgba(0, 0, ...      Calvin Johnson
# 2      <a   class="nt_btn " style="color: rgba(0, 0, ...       David Buehler
# 3      <a   class="nt_btn " style="color: rgba(0, 0, ...  Anthony Richardson
# 4      <a   class="nt_btn " style="color: rgba(0, 0, ...      Lorenzo Carter
# ...                                                  ...                 ...
# 10101  <a   class="nt_btn " style="color: rgba(0, 0, ...       Sataoa Laumea
# 10102  <a   class="nt_btn " style="color: rgba(0, 0, ...       Will Reichard
# 10103  <a   class="nt_btn " style="color: rgba(0, 0, ...          Nick Samac
# 10104  <a   class="nt_btn " style="color: rgba(0, 0, ...  LaDarius Henderson
# 10105  <a   class="nt_btn " style="color: rgba(0, 0, ...     Jonathon Brooks
#
#       Pos  Year              College   RAS  Alltime
# 0      RB  2003  Southern California  10.0     10.0
# 1      WR  2007         Georgia Tech  10.0     10.0
# 2      PK  2009  Southern California  10.0     10.0
# 3      QB  2023              Florida  10.0     10.0
# 4      LB  2018              Georgia  10.0     10.0
# ...    ..   ...                  ...   ...      ...
# 10101  OG  2024                 Utah   NaN      NaN
# 10102  PK  2024              Alabama   NaN      NaN
# 10103  OC  2024       Michigan State   NaN      NaN
# 10104  OG  2024             Michigan   NaN      NaN
# 10105  RB  2024                Texas   NaN      NaN
#
# [10106 rows x 7 columns]

# %%
RAINBOW_COLORS: list = ["#ffadad","#ffd6a5","#fdffb6","#caffbf","#9bf6ff","#a0c4ff","#bdb2ff","#ffc6ff"]
POS_RAINBOW_COLOR_SEQ: list = [RAINBOW_COLORS[i % len(RAINBOW_COLORS)] for i in range(len(np.unique(RAS_2025['Pos'])))]

RAS_2025_by_pos = px.bar(
    data_frame=pd.DataFrame(
        {
            'Position': [val[0] for val in RAS_2025.value_counts(subset = ['Pos']).index.to_flat_index()],
            'Counts': RAS_2025.value_counts(subset = ['Pos']).values
        }
    ),
    x = 'Position',
    y = 'Counts',
    template = 'plotly_dark'
)

RAS_2025_by_pos.update_layout(
    font_family = "Raleway, sans-serif",
    title = dict(text = '<b>2025 RAS Scores by Position</b> <br><em>As of 4/15/25</em>', x = .5, xanchor='center', font = {'size': 20})
)

for bar in RAS_2025_by_pos.data:
    bar.marker.color = POS_RAINBOW_COLOR_SEQ

# RAS_2025_by_pos.write_image('../img/RAS_scores_by_position.png', engine = 'kaleido', scale = 6)

# %% [markdown]
# ![RAS Scores by Position](../img/RAS_scores_by_position.png?123)

# %%
RAS_parsed: pd.DataFrame = all_RAS.loc[(all_RAS['Year'] >= 2021) & (all_RAS['Pos'] == 'WR')].dropna(axis = 0, subset = ['RAS', 'Name'])
RAS_parsed
# Out:
#                                                    Link                 Name  \
# 33    <a   class="nt_btn " style="color: rgba(0, 0, ...      Adonai Mitchell
# 90    <a   class="nt_btn " style="color: rgba(0, 0, ...     Christian Watson
# 91    <a   class="nt_btn " style="color: rgba(0, 0, ...       Andrei Iosivas
# 129   <a   class="nt_btn " style="color: rgba(0, 0, ...         Dareke Young
# 164   <a   class="nt_btn " style="color: rgba(0, 0, ...          Rome Odunze
# ...                                                 ...                  ...
# 5769  <a   class="nt_btn " style="color: rgba(0, 0, ...  Montrell Washington
# 5833  <a   class="nt_btn " style="color: rgba(0, 0, ...         Derius Davis
# 5962  <a   class="nt_btn " style="color: rgba(0, 0, ...           David Bell
# 6898  <a   class="nt_btn " style="color: rgba(0, 0, ...         Dazz Newsome
# 7428  <a   class="nt_btn " style="color: rgba(0, 0, ...      Demetric Felton
#
#      Pos  Year             College   RAS  Alltime
# 33    WR  2024               Texas  9.99     9.99
# 90    WR  2022  North Dakota State  9.96     9.96
# 91    WR  2023           Princeton  9.96     9.96
# 129   WR  2022        Lenoir-Rhyne  9.93     9.94
# 164   WR  2024          Washington  9.92     9.92
# ...   ..   ...                 ...   ...      ...
# 5769  WR  2022             Samford  4.32     4.51
# 5833  WR  2023     Texas Christian  4.29     4.40
# 5962  WR  2022              Purdue  3.98     4.18
# 6898  WR  2021      North Carolina  2.13     2.41
# 7428  WR  2021                UCLA  0.87     1.01
#
# [122 rows x 7 columns]

# %%
RAS_2025_receivers: pd.DataFrame = RAS_2025.loc[RAS_2025['Pos'] == 'WR'].dropna(axis = 0, subset = ['RAS', 'Name'])
RAS_2025_receivers
# Out:
#                                                    Link             Name Pos  \
# 5     <a   class="nt_btn " style="color: rgba(0, 0, ...    Landon Parker  WR
# 7     <a   class="nt_btn " style="color: rgba(0, 0, ...     Isaac TeSlaa  WR
# 13    <a   class="nt_btn " style="color: rgba(0, 0, ...     Isaiah Neyor  WR
# 14    <a   class="nt_btn " style="color: rgba(0, 0, ...        Sam Brown  WR
# 18    <a   class="nt_btn " style="color: rgba(0, 0, ...  Dont'e Thornton  WR
# ...                                                 ...              ...  ..
# 2519  <a   class="nt_btn " style="color: rgba(0, 0, ...    Steven Alaniz  WR
# 2522  <a   class="nt_btn " style="color: rgba(0, 0, ...         Ty Wiley  WR
# 2523  <a   class="nt_btn " style="color: rgba(0, 0, ...    Terez Traynor  WR
# 2536  <a   class="nt_btn " style="color: rgba(0, 0, ...      Dejuan Bell  WR
# 2537  <a   class="nt_btn " style="color: rgba(0, 0, ...        Beau Burk  WR
#
#       Year                 College   RAS  Alltime RAS
# 5     2025                    Troy  9.97         9.97
# 7     2025                Arkansas  9.93         9.93
# 13    2025                Nebraska  9.90         9.90
# 14    2025                   Miami  9.90         9.90
# 18    2025               Tennessee  9.85         9.85
# ...    ...                     ...   ...          ...
# 2519  2025                 Capital  0.12         0.12
# 2522  2025          Northern State  0.10         0.10
# 2523  2025               Charlotte  0.10         0.10
# 2536  2025       Fort Valley State  0.07         0.07
# 2537  2025  Northwestern Minnesota  0.07         0.07
#
# [414 rows x 7 columns]

# %%
YEARS = [num for num in range(2021, 2025)]
STAT_YEARS = [num for num in range(2019, 2025)]

# %%
from typing import Callable, Any, Type
from cfbd.api_response import ApiResponse  

import cfbd.api_response

def get_cfbd_data(config: cfbd.Configuration, years: list[int], api_instance: str, api_call: str, filepath: str, display_usage: bool = False, load: bool = True, **kwargs) -> pd.DataFrame:
    """call the CFBD api multiple times, conglomerate the data, save it to a CSV and dataframe, and then return the dataframe

    Args:
        config (cfbd.Configuration): configuration object to authenticate the CFBD api
        years (list[int]): years to collect the data for 
        api_instance (str): the specific unauthenticated API type from CFBD where the specific API call is housed
        api_call (str): specific API call that you'd like to make for each year
        filepath (str): filepath to either write the file to (if load = True) or read from (if false)
        display_usage (bool, optional): display the number of API calls remaining for a given API key. Defaults to False.
        load (bool, optional): whether to load a dataset from an existing filepath. Defaults to True.

    Returns:
        pd.DataFrame: dataframe of requested statistics, either loaded or collected from the API
    """
    data: list = []
    if not load:
        with cfbd.ApiClient(config) as api:
            # Get the desired class from the cfbd module
            api_class: Type[Any] = getattr(cfbd, api_instance)
            authenticated_api_instance: Any = api_class(api)
            for year in years:
                # Get the method from the class
                retrieved_api_call: Callable[...,Any] = getattr(authenticated_api_instance, api_call)

                # Make the API call (finally...)
                response: ApiResponse = retrieved_api_call(year = year, **kwargs)

                # Add this data to our list
                data.extend([dict(player) for player in response.data])

                if display_usage:
                    print(f"The amount of API calls left is: {response.headers['X-Calllimit-Remaining']}")
        
        df: pd.DataFrame = pd.DataFrame(data)
        
        # To avoid having to run these API calls every time, we save the file
        df.to_csv(filepath)
    else:
        # In case we already have the file saved, just read it
        df: pd.DataFrame = pd.read_csv(filepath)
    
    return df

# %%
player_season_stats: pd.DataFrame = get_cfbd_data(
    config = configuration,
    years = STAT_YEARS,
    api_instance = "StatsApi",
    api_call = 'get_player_season_stats_with_http_info',
    filepath = './datasets/cfbd_player_season_stats_2021_2025.csv',
    display_usage = True,
    load = True,
)

# There's some weird extra whitespace that the following line will remove
player_season_stats = player_season_stats.applymap(lambda x: x.strip() if isinstance(x, str) else x)

player_season_stats
# Out:
#         Unnamed: 0  season  player_id         player                team  \
# 0                0    2019    -109170           Team      Kennesaw State
# 1                1    2019    -109170           Team      Kennesaw State
# 2                2    2019    -109170           Team      Kennesaw State
# 3                3    2019    -109170           Team      Kennesaw State
# 4                4    2019    -109170           Team      Kennesaw State
# ...            ...     ...        ...            ...                 ...
# 733345      733345    2024    5257802  Fred Davis Ii  Jacksonville State
# 733346      733346    2024    5257802  Fred Davis Ii  Jacksonville State
# 733347      733347    2024    5257802  Fred Davis Ii  Jacksonville State
# 733348      733348    2024    5257802  Fred Davis Ii  Jacksonville State
# 733349      733349    2024    5257802  Fred Davis Ii  Jacksonville State
#
#             conference   category stat_type  stat
# 0            Big South    rushing       CAR   1.0
# 1            Big South    rushing      LONG   0.0
# 2            Big South    rushing        TD   0.0
# 3            Big South    rushing       YDS  -2.0
# 4            Big South    rushing       YPC  -2.0
# ...                ...        ...       ...   ...
# 733345  Conference USA  defensive     SACKS   0.0
# 733346  Conference USA  defensive      SOLO   1.0
# 733347  Conference USA  defensive        TD   0.0
# 733348  Conference USA  defensive       TFL   1.0
# 733349  Conference USA  defensive       TOT   1.0
#
# [733350 rows x 9 columns]

# %%
player_predicted_points_added: pd.DataFrame = get_cfbd_data(
    config = configuration,
    years = STAT_YEARS,
    api_instance = "MetricsApi",
    api_call = 'get_predicted_points_added_by_player_season_with_http_info',
    filepath = './datasets/cfbd_player_predicted_points_added_2021_2025.csv',
    display_usage = True,
    load = True,
)

player_predicted_points_added
# Out:
#        Unnamed: 0  season       id               name position  \
# 0               0    2019  4030745  Maurice Lewis Jr.       WR
# 1               1    2019  4258190          Ben Mason       TE
# 2               2    2019  4372368     T.K. Wilkerson       RB
# 3               3    2019  4036529     Jonathan Ifedi       WR
# 4               4    2019  4240546   Michael Marchese       TE
# ...           ...     ...      ...                ...      ...
# 15324       15324    2024  5159888         Chris Elko       WR
# 15325       15325    2024  5193217     Jonathan Bibbs       WR
# 15326       15326    2024  5147367       Joseph McVay       WR
# 15327       15327    2024  5079382    Jonathan Echols       TE
# 15328       15328    2024  4431246          Baron May       QB
#
#                  team         conference  \
# 0       Bowling Green       Mid-American
# 1            Michigan            Big Ten
# 2      San José State      Mountain West
# 3      Arkansas State           Sun Belt
# 4               UConn  American Athletic
# ...               ...                ...
# 15324    Georgia Tech                ACC
# 15325       UL Monroe           Sun Belt
# 15326      Vanderbilt                SEC
# 15327   South Florida  American Athletic
# 15328   Bowling Green       Mid-American
#
#                                              average_ppa  \
# 0      passing_downs=0 standard_downs=-4.924 third_do...
# 1      passing_downs=0 standard_downs=-4.393 third_do...
# 2      passing_downs=0 standard_downs=-3.958 third_do...
# 3      passing_downs=0 standard_downs=-3.811 third_do...
# 4      passing_downs=0 standard_downs=-3.811 third_do...
# ...                                                  ...
# 15324  passing_downs=0 standard_downs=4.865 third_dow...
# 15325  passing_downs=0 standard_downs=5.243 third_dow...
# 15326  passing_downs=0 standard_downs=5.243 third_dow...
# 15327  passing_downs=0 standard_downs=6.007 third_dow...
# 15328  passing_downs=0 standard_downs=6.9 third_down=...
#
#                                                total_ppa
# 0      passing_downs=0 standard_downs=-4.924 third_do...
# 1      passing_downs=0 standard_downs=-8.786 third_do...
# 2      passing_downs=0 standard_downs=-3.958 third_do...
# 3      passing_downs=0 standard_downs=-3.811 third_do...
# 4      passing_downs=0 standard_downs=-3.811 third_do...
# ...                                                  ...
# 15324  passing_downs=0 standard_downs=4.865 third_dow...
# 15325  passing_downs=0 standard_downs=10.485 third_do...
# 15326  passing_downs=0 standard_downs=10.485 third_do...
# 15327  passing_downs=0 standard_downs=12.015 third_do...
# 15328  passing_downs=0 standard_downs=13.801 third_do...
#
# [15329 rows x 9 columns]

# %%
receiving_stats: pd.DataFrame = player_season_stats.loc[(player_season_stats['player'] != 'Team') & (player_season_stats['category'] == 'receiving')]

# Instead of each player have multiple rows with every row being a different stat, just have one row with each stat being its own column 
receiving_stats = receiving_stats.pivot(
    index = ['player_id','player', 'season'],
    columns = 'stat_type',
    values = 'stat',
).reset_index()

# %%
receiving_stats
# Out:
# stat_type  player_id            player  season  LONG  REC   TD    YDS   YPR
# 0             102597       Will Rogers    2022  13.0  1.0  0.0   13.0  13.0
# 1             107494      Trey Sanders    2020   0.0  1.0  0.0   -2.0  -2.0
# 2             107494      Trey Sanders    2021  36.0  6.0  0.0   55.0   9.2
# 3             107494      Trey Sanders    2022  10.0  2.0  0.0   13.0   6.5
# 4             107494      Trey Sanders    2023   8.0  5.0  0.0   20.0   4.0
# ...              ...               ...     ...   ...  ...  ...    ...   ...
# 20637        5243750         Tj Holmes    2024   8.0  1.0  0.0    8.0   8.0
# 20638        5243771       Carlos Mann    2024  21.0  2.0  0.0   30.0  15.0
# 20639        5245626  Brennen Benedict    2024   6.0  1.0  0.0    6.0   6.0
# 20640        5245627           Cj Broy    2024  61.0  9.0  2.0  143.0  15.9
# 20641        5257510   Kenneth Law Jr.    2024  11.0  2.0  0.0   19.0   9.5
#
# [20642 rows x 8 columns]

# %%
def extract_ppa_from_table(val: str, prefix: str) -> dict:
    vals: list[str] = val.split(' ')
    extracted_dict: dict[str, float] = {}
    for val in vals:
        extract = val.split('=')
        extracted_dict[f'{prefix}_{extract[0]}_ppa'] = float(extract[1])
    
    return extracted_dict

# %%
# We have to unpack our player_predicted_points_added dataframe a bit
player_predicted_points_added_expanded: pd.DataFrame = pd.json_normalize(player_predicted_points_added['average_ppa'].map(lambda x: extract_ppa_from_table(x, 'average')))

# Let's also extract the total PPA values 
player_predicted_points_added_total: pd.DataFrame = pd.json_normalize(player_predicted_points_added['total_ppa'].map(lambda x: extract_ppa_from_table(x, 'total')))

# Now join these expanded datasets with the original player data
player_predicted_points_combined = pd.concat([
    player_predicted_points_added.drop(['average_ppa', 'total_ppa'], axis=1).reset_index(drop=True),
    player_predicted_points_added_expanded.reset_index(drop=True),
    player_predicted_points_added_total.reset_index(drop=True)
], axis=1)


player_predicted_points_combined
# Out:
#        Unnamed: 0  season       id               name position  \
# 0               0    2019  4030745  Maurice Lewis Jr.       WR
# 1               1    2019  4258190          Ben Mason       TE
# 2               2    2019  4372368     T.K. Wilkerson       RB
# 3               3    2019  4036529     Jonathan Ifedi       WR
# 4               4    2019  4240546   Michael Marchese       TE
# ...           ...     ...      ...                ...      ...
# 15324       15324    2024  5159888         Chris Elko       WR
# 15325       15325    2024  5193217     Jonathan Bibbs       WR
# 15326       15326    2024  5147367       Joseph McVay       WR
# 15327       15327    2024  5079382    Jonathan Echols       TE
# 15328       15328    2024  4431246          Baron May       QB
#
#                  team         conference  average_passing_downs_ppa  \
# 0       Bowling Green       Mid-American                        0.0
# 1            Michigan            Big Ten                        0.0
# 2      San José State      Mountain West                        0.0
# 3      Arkansas State           Sun Belt                        0.0
# 4               UConn  American Athletic                        0.0
# ...               ...                ...                        ...
# 15324    Georgia Tech                ACC                        0.0
# 15325       UL Monroe           Sun Belt                        0.0
# 15326      Vanderbilt                SEC                        0.0
# 15327   South Florida  American Athletic                        0.0
# 15328   Bowling Green       Mid-American                        0.0
#
#        average_standard_downs_ppa  average_third_down_ppa  ...  \
# 0                          -4.924                   0.000  ...
# 1                          -4.393                   0.000  ...
# 2                          -3.958                  -3.958  ...
# 3                          -3.811                   0.000  ...
# 4                          -3.811                   0.000  ...
# ...                           ...                     ...  ...
# 15324                       4.865                   0.000  ...
# 15325                       5.243                   0.000  ...
# 15326                       5.243                   0.000  ...
# 15327                       6.007                   6.007  ...
# 15328                       6.900                   0.000  ...
#
#        average_var_pass_ppa  average_all_ppa  total_passing_downs_ppa  \
# 0                    -4.924           -4.924                      0.0
# 1                     0.000           -4.393                      0.0
# 2                     0.000           -3.958                      0.0
# 3                    -3.811           -3.811                      0.0
# 4                    -3.811           -3.811                      0.0
# ...                     ...              ...                      ...
# 15324                 4.865            4.865                      0.0
# 15325                 5.243            5.243                      0.0
# 15326                 5.243            5.243                      0.0
# 15327                 6.007            6.007                      0.0
# 15328                 6.900            6.900                      0.0
#
#        total_standard_downs_ppa  total_third_down_ppa  total_second_down_ppa  \
# 0                        -4.924                 0.000                 -4.924
# 1                        -8.786                 0.000                 -8.786
# 2                        -3.958                -3.958                  0.000
# 3                        -3.811                 0.000                  0.000
# 4                        -3.811                 0.000                  0.000
# ...                         ...                   ...                    ...
# 15324                     4.865                 0.000                  0.000
# 15325                    10.485                 0.000                  0.000
# 15326                    10.485                 0.000                  0.000
# 15327                    12.015                12.015                  0.000
# 15328                    13.801                 0.000                  0.000
#
#        total_first_down_ppa  total_rush_ppa  total_var_pass_ppa  total_all_ppa
# 0                     0.000           0.000              -4.924         -4.924
# 1                     0.000          -8.786               0.000         -8.786
# 2                     0.000          -3.958               0.000         -3.958
# 3                    -3.811           0.000              -3.811         -3.811
# 4                    -3.811           0.000              -3.811         -3.811
# ...                     ...             ...                 ...            ...
# 15324                 0.000           0.000               4.865          4.865
# 15325                10.485           0.000              10.485         10.485
# 15326                10.485           0.000              10.485         10.485
# 15327                 0.000           0.000              12.015         12.015
# 15328                 0.000           0.000              13.801         13.801
#
# [15329 rows x 23 columns]

# %%
def get_combine_data(years: list[int], positions: list[str], filepath: str, load: bool = True) -> pd.DataFrame:
    """scrape nflcombineresults.com to get combine data 

    Args:
        years (list[int]): list of integers for combine data to get
        positions (list[str]): list of positions to get combine data for
        filepath (str): filepath to either write the file to (if load = True) or read from (if false)
        load (bool, optional): whether to load a dataset from an existing filepath. Defaults to True.
    Returns:
        pd.DataFrame: data frame of all combine data
    """
    if not load:
        all_data = []
        
        for year in years:
            for position in positions:
                url = f'https://nflcombineresults.com/nflcombinedata.php?year={year}&pos={position}&college='
                
                # Add a small delay to avoid overloading the server
                sleep(1)
                
                try:
                    response = requests.get(url) # even though this throws a 404 error, the website still loads?? bizarre
                    
                    # Parse the HTML table with BeautifulSoup
                    soup = BeautifulSoup(response.text, 'html.parser')
                    
                    # Find the table containing combine data
                    table = soup.find('table')
                    
                    if table:
                        # Extract data rows
                        rows = table.find_all('tr')[1:]
                        for row in rows: 
                            cells = row.find_all('td')
                            if len(cells) == 13:
                                row_data = {
                                    'year': cells[0].text,
                                    'name': cells[1].text,
                                    'college': cells[2].text,
                                    'pos': cells[3].text,
                                    'height': cells[4].text,
                                    'weight': cells[5].text,
                                    'forty': cells[7].text,
                                    'bench': cells[8].text,
                                    'vertical': cells[9].text,
                                    'broad jump': cells[10].text,
                                    'shuttle': cells[11].text,
                                    '3-cone': cells[12].text
                                }
                                
                                
                                all_data.append(row_data)
                        
                        print(f"Successfully scraped data for {year} {position}")
                    else:
                        print(f"No data table found for {year} {position}")
                        
                except requests.exceptions.RequestException as e:
                    print(f"Error fetching data for {year} {position}: {e}")
        
        
            df = pd.DataFrame(all_data)
            df.to_csv(filepath)
    else:
        df = pd.read_csv(filepath)

    
    return df

# %%
nfl_data: pd.DataFrame = nfl.import_seasonal_rosters(years = YEARS)

# %%
combine_data: pd.DataFrame = get_combine_data(years = YEARS, positions=['WR'], filepath = './datasets/combine_data_2021_2025.csv', load = True)

# %%
combine_data
# Out:
#      Unnamed: 0  year                 name         college pos  height  \
# 0             0  2021       Jonathan Adams  Arkansas State  WR   74.00
# 1             1  2021          Tutu Atwell      Louisville  WR   68.88
# 2             2  2021        Jhamon Ausbon       Texas A&M  WR   74.38
# 3             3  2021         Kawaan Baker   South Alabama  WR   72.50
# 4             4  2021       Rashod Bateman       Minnesota  WR   72.38
# ..          ...   ...                  ...             ...  ..     ...
# 195         196  2024     Casey Washington        Illinois  WR   72.88
# 196         197  2021            Dax Milne   Brigham Young  WR   72.63
# 197         198  2021      Demetric Felton            UCLA  WR   68.62
# 198         199  2022         Samori Toure        Nebraska  WR   72.75
# 199         200  2022  Montrell Washington         Samford  WR   68.88
#
#      weight  forty  bench  vertical  broad jump  shuttle  3-cone
# 0       210   4.59    NaN      39.0       132.0     4.38    7.04
# 1       155   4.39    NaN      33.0       117.0     4.09    6.87
# 2       217   4.72    NaN      33.0       118.0     4.28    6.89
# 3       210   4.45   21.0      39.5       129.0     4.41    7.42
# 4       190   4.43    NaN      36.0       123.0     4.35    6.95
# ..      ...    ...    ...       ...         ...      ...     ...
# 195     201   4.46   13.0      39.5       127.0     4.43    7.39
# 196     193   4.56   14.0      31.0       114.0     4.22    6.85
# 197     189   4.59   10.0      31.5       114.0     4.50    7.31
# 198     191   4.48    7.0      34.5       124.0     4.22    6.77
# 199     176   4.48    6.0      36.0       124.0     4.32    7.25
#
# [200 rows x 13 columns]

# %%
def convert_fiie_to_in(fiie: int) -> float:
    """convert a fiie height to inches

    Args:
        fiie (int): height in fiie

    Returns:
        float: height in inches, rounded to closest hundredth of an inch
    """
    fiie_str: str = str(fiie)
    feet: str = fiie_str[0]
    inches: str = fiie_str[1:3]
    eighth_of_inch: str = fiie_str[3]

    height: float = (int(feet) * 12) + int(inches) + (int(eighth_of_inch) * (1/8))

    return round(height, 2)

# %%
combine_data_2025 = pd.read_csv('./datasets/2025 Combine for WRs.csv')

# Convert FIIE heights to inches to match the rest of the data 
combine_data_2025['height'] = combine_data_2025['height'].apply(func = convert_fiie_to_in)

combine_data_2025
# Out:
#                      name            School  year Position  Drafted By  Age  \
# 0        Andrew Armstrong          Arkansas  2025       WR         NaN  NaN
# 1           Elic Ayomanor          Stanford  2025       WR         NaN  NaN
# 2          Elijhah Badger           Florida  2025       WR         NaN  NaN
# 3               Jack Bech               TCU  2025       WR         NaN  NaN
# 4             Isaiah Bond             Texas  2025       WR         NaN  NaN
# 5         Ja'Corey Brooks        Louisville  2025       WR         NaN  NaN
# 6           Sam Brown Jr.             Miami  2025       WR         NaN  NaN
# 7              Pat Bryant          Illinois  2025       WR         NaN  NaN
# 8       Luther Burden III          Missouri  2025       WR         NaN  NaN
# 9           Beaux Collins        Notre Dame  2025       WR         NaN  NaN
# 10           Chimere Dike           Florida  2025       WR         NaN  NaN
# 11           Emeka Egbuka        Ohio State  2025       WR         NaN  NaN
# 12         Da'Quan Felton     Virginia Tech  2025       WR         NaN  NaN
# 13             Tai Felton          Maryland  2025       WR         NaN  NaN
# 14         Jacolby George             Miami  2025       WR         NaN  NaN
# 15         Matthew Golden             Texas  2025       WR         NaN  NaN
# 16             Tre Harris          Ole Miss  2025       WR         NaN  NaN
# 17         Jayden Higgins        Iowa State  2025       WR         NaN  NaN
# 18        Traeshon Holden            Oregon  2025       WR         NaN  NaN
# 19         Jimmy Horn Jr.          Colorado  2025       WR         NaN  NaN
# 20            Tory Horton    Colorado State  2025       WR         NaN  NaN
# 21            Kobe Hudson               UCF  2025       WR         NaN  NaN
# 22         Daniel Jackson         Minnesota  2025       WR         NaN  NaN
# 23            Tez Johnson            Oregon  2025       WR         NaN  NaN
# 24             Josh Kelly        Texas Tech  2025       WR         NaN  NaN
# 25  KeAndre Lambert-Smith            Auburn  2025       WR         NaN  NaN
# 26            Jaylin Lane     Virginia Tech  2025       WR         NaN  NaN
# 27         Dominic Lovett           Georgia  2025       WR         NaN  NaN
# 28              Bru McCoy         Tennessee  2025       WR         NaN  NaN
# 29      Tetairoa McMillan           Arizona  2025       WR         NaN  NaN
# 30       Konata Mumpfield        Pittsburgh  2025       WR         NaN  NaN
# 31              Nick Nash      San Jose St.  2025       WR         NaN  NaN
# 32           Isaiah Neyor          Nebraska  2025       WR         NaN  NaN
# 33            Jaylin Noel        Iowa State  2025       WR         NaN  NaN
# 34          Kaden Prather          Maryland  2025       WR         NaN  NaN
# 35        Xavier Restrepo             Miami  2025       WR         NaN  NaN
# 36           Jalen Royals        Utah State  2025       WR         NaN  NaN
# 37            Arian Smith           Georgia  2025       WR         NaN  NaN
# 38             Roc Taylor           Memphis  2025       WR         NaN  NaN
# 39           Isaac TeSlaa          Arkansas  2025       WR         NaN  NaN
# 40    Dont'e Thornton Jr.         Tennessee  2025       WR         NaN  NaN
# 41         Jordan Watkins          Ole Miss  2025       WR         NaN  NaN
# 42         Theo Wease Jr.          Missouri  2025       WR         NaN  NaN
# 43      Antwane Wells Jr.          Ole Miss  2025       WR         NaN  NaN
# 44       LaJohntay Wester          Colorado  2025       WR         NaN  NaN
# 45        Ricky White III              UNLV  2025       WR         NaN  NaN
# 46          Kyle Williams  Washington State  2025       WR         NaN  NaN
# 47        Savion Williams               TCU  2025       WR         NaN  NaN
#
#     height  weight  Arm Length (inches)  Hand Span (inches)  \
# 0    75.75     202               32.125               9.500
# 1    73.75     206               32.375              10.000
# 2    73.38     200               32.375               9.500
# 3    73.25     214               31.500               9.000
# 4    70.62     180               30.500               8.500
# 5    74.00     184               31.625               9.000
# 6    74.25     200               31.500               9.380
# 7    74.25     204               31.125               9.500
# 8    72.00     206               31.250               8.500
# 9    75.00     201               31.500               9.500
# 10   72.62     196               32.125               9.125
# 11   72.88     202               31.500               9.500
# 12   76.25     213               32.250               9.000
# 13   73.12     183               30.000               9.000
# 14   71.00     172               31.375               9.500
# 15   71.00     191               30.500               9.500
# 16   74.38     205               31.750               9.500
# 17   76.12     214               33.125               9.125
# 18   74.12     205               31.500               9.750
# 19   68.12     174               30.375               8.625
# 20   74.50     196               30.500               9.000
# 21   72.75     193               30.500               9.000
# 22   70.75     193               30.625               9.000
# 23   69.88     154               29.375               9.000
# 24   72.62     186               30.750              10.500
# 25   72.75     190               32.500               9.125
# 26   69.75     191               31.675               9.750
# 27   70.00     185               31.375               9.250
# 28   74.50     209               32.125              10.000
# 29   76.12     219               31.500              10.000
# 30   71.38     186               29.375               8.500
# 31   74.50     203               31.000               8.625
# 32   76.25     218               34.375               9.500
# 33   70.25     194               29.500               8.625
# 34   75.50     204               31.750               9.250
# 35   69.88     209               29.375               9.125
# 36   72.00     205               30.125               9.500
# 37   72.12     179               31.250               9.000
# 38   73.88     213               32.250               9.000
# 39   75.62     214               31.125              10.000
# 40   76.62     205               32.125               9.500
# 41   71.25     196               29.375               9.125
# 42   75.00     200               32.125               9.500
# 43   72.75     201               31.500               8.750
# 44   69.62     163               29.625               8.500
# 45   73.12     184               31.625               9.250
# 46   70.62     190               30.125               8.625
# 47   75.88     222               32.500              10.250
#
#     Bench Press (reps)  forty  10-yard Split (seconds)  \
# 0                 11.0   4.51                     1.53
# 1                  NaN   4.44                     1.58
# 2                  NaN   4.43                     1.53
# 3                  NaN    NaN                      NaN
# 4                  NaN   4.39                     1.51
# 5                  NaN    NaN                      NaN
# 6                  NaN   4.44                     1.52
# 7                  NaN   4.61                     1.56
# 8                  NaN   4.41                     1.54
# 9                  NaN    NaN                      NaN
# 10                 NaN   4.34                     1.51
# 11                 NaN    NaN                      NaN
# 12                 NaN   4.50                     1.52
# 13                 NaN   4.37                     1.51
# 14                 NaN    NaN                      NaN
# 15                 NaN   4.29                     1.49
# 16                 NaN   4.54                     1.56
# 17                 NaN   4.47                     1.53
# 18                 NaN   4.57                     1.54
# 19                 NaN   4.46                     1.54
# 20                 NaN   4.41                     1.53
# 21                 NaN   4.57                     1.54
# 22                 NaN    NaN                      NaN
# 23                 NaN   4.51                     1.53
# 24                 NaN   4.70                     1.56
# 25                 NaN   4.37                     1.53
# 26                14.0   4.34                     1.50
# 27                 NaN   4.40                     1.53
# 28                 NaN    NaN                      NaN
# 29                 NaN    NaN                      NaN
# 30                 NaN   4.59                     1.54
# 31                 NaN   4.57                     1.54
# 32                 NaN   4.40                     1.51
# 33                23.0   4.39                     1.51
# 34                 NaN   4.46                     1.53
# 35                17.0    NaN                      NaN
# 36                13.0   4.42                     1.49
# 37                 NaN   4.36                     1.51
# 38                 NaN   4.49                     1.53
# 39                17.0   4.43                     1.51
# 40                 NaN   4.30                     1.51
# 41                 NaN   4.37                     1.53
# 42                 NaN   4.56                     1.56
# 43                 NaN   4.58                     1.53
# 44                 NaN   4.46                     1.53
# 45                 NaN   4.61                     1.55
# 46                 NaN   4.40                     1.55
# 47                 NaN   4.48                     1.52
#
#     20-yard Split (seconds)  20-yard Shuttle (seconds)  \
# 0                       NaN                       4.18
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                       4.21
# 4                       NaN                        NaN
# 5                       NaN                        NaN
# 6                       NaN                        NaN
# 7                       NaN                        NaN
# 8                       NaN                        NaN
# 9                       NaN                        NaN
# 10                      NaN                       4.27
# 11                      NaN                        NaN
# 12                      NaN                       4.30
# 13                      NaN                        NaN
# 14                      NaN                        NaN
# 15                      NaN                        NaN
# 16                      NaN                        NaN
# 17                      NaN                        NaN
# 18                      NaN                        NaN
# 19                      NaN                       4.41
# 20                      NaN                        NaN
# 21                      NaN                        NaN
# 22                      NaN                       4.07
# 23                      NaN                       4.15
# 24                      NaN                        NaN
# 25                      NaN                        NaN
# 26                      NaN                       4.12
# 27                      NaN                        NaN
# 28                      NaN                        NaN
# 29                      NaN                        NaN
# 30                      NaN                        NaN
# 31                      NaN                        NaN
# 32                      NaN                        NaN
# 33                      NaN                       4.17
# 34                      NaN                        NaN
# 35                      NaN                        NaN
# 36                      NaN                        NaN
# 37                      NaN                       4.19
# 38                      NaN                        NaN
# 39                      NaN                       4.05
# 40                      NaN                        NaN
# 41                      NaN                        NaN
# 42                      NaN                        NaN
# 43                      NaN                        NaN
# 44                      NaN                        NaN
# 45                      NaN                        NaN
# 46                      NaN                        NaN
# 47                      NaN                        NaN
#
#     Three-cone Drill (seconds)  Vertical Jump (inches)  Broad Jump (FFII)  \
# 0                         6.97                    37.5             1004.0
# 1                          NaN                    38.5             1007.0
# 2                          NaN                    35.5                NaN
# 3                         6.84                    34.5             1005.0
# 4                          NaN                     NaN                NaN
# 5                          NaN                     NaN                NaN
# 6                          NaN                    41.5                NaN
# 7                          NaN                    37.5             1004.0
# 8                          NaN                     NaN                NaN
# 9                          NaN                     NaN                NaN
# 10                        6.82                    38.5             1008.0
# 11                         NaN                     NaN                NaN
# 12                        7.10                    32.5             1002.0
# 13                         NaN                    39.5             1010.0
# 14                        6.77                    32.5             1000.0
# 15                         NaN                     NaN                NaN
# 16                         NaN                    38.5             1005.0
# 17                         NaN                    39.0             1008.0
# 18                         NaN                    32.0             1003.0
# 19                         NaN                    38.0             1008.0
# 20                         NaN                    37.5                NaN
# 21                         NaN                    35.0             1002.0
# 22                        6.78                     NaN                NaN
# 23                        6.65                    37.0             1011.0
# 24                        7.02                    33.0             1001.0
# 25                         NaN                    34.0             1004.0
# 26                        6.75                    40.0             1100.0
# 27                         NaN                    33.5             1000.0
# 28                         NaN                     NaN                NaN
# 29                         NaN                     NaN                NaN
# 30                         NaN                    36.0             1004.0
# 31                         NaN                    34.0             1003.0
# 32                         NaN                    38.0             1101.0
# 33                        6.82                    41.5             1102.0
# 34                         NaN                    30.0              906.0
# 35                         NaN                     NaN                NaN
# 36                         NaN                     NaN                NaN
# 37                        6.82                    38.0             1007.0
# 38                         NaN                    30.5             1002.0
# 39                        6.85                    39.5             1009.0
# 40                         NaN                    33.0             1006.0
# 41                         NaN                    36.5              911.0
# 42                         NaN                    31.0              909.0
# 43                         NaN                    34.0             1004.0
# 44                         NaN                    32.0             1001.0
# 45                         NaN                    36.0             1003.0
# 46                         NaN                    36.5              911.0
# 47                         NaN                     NaN                NaN
#
#       RAS  Production
# 0    9.06         7.0
# 1    9.67         7.3
# 2    9.44         6.8
# 3    9.46         6.8
# 4     NaN         6.5
# 5     NaN         6.8
# 6    9.87         5.8
# 7    8.19         7.1
# 8     NaN         7.8
# 9     NaN         5.8
# 10   9.65         6.0
# 11    NaN         7.8
# 12   8.21         6.1
# 13   9.60         7.4
# 14    NaN         6.7
# 15    NaN         7.4
# 16   9.02         7.6
# 17   9.85         7.8
# 18   6.43         6.4
# 19   6.11         5.8
# 20   9.71         6.9
# 21   5.85         6.6
# 22    NaN         6.6
# 23   7.66         7.4
# 24   2.55         6.9
# 25    NaN         6.7
# 26   9.56         6.4
# 27   6.77         6.5
# 28    NaN         5.9
# 29    NaN         8.4
# 30   6.01         6.4
# 31    NaN         7.2
# 32  10.00         6.4
# 33   9.71         8.0
# 34   7.40         6.1
# 35    NaN         7.4
# 36   9.27         7.6
# 37   9.43         6.2
# 38   8.55         6.1
# 39   9.97         5.3
# 40   9.83         6.2
# 41   8.77         6.5
# 42   6.35         6.5
# 43   7.37         6.7
# 44   4.90         6.6
# 45   6.12         7.8
# 46   7.84         7.6
# 47    NaN         7.2

# %%
def get_val(player_name: str, col_name: str, dataframe: pd.DataFrame, year: int, year_name_col: str ='year', player_name_col: str = 'name', verbose: bool = False) -> float:
    """Filter a dataframe to find the specific statistic for a player in a particular year
    Args:
        player_name (str): name of the player
        col_name (str): name of the column that holds the desired statistic
        dataframe (pd.DataFrame): dataframe to filter with
        year (int): year where statistic was captured
        year_name_col (str, optional): name of the year column for the dataframe. Defaults to 'year'.
        player_name_col (str, optional): name of the player_name column for the dataframe. Defaults to 'name'.
        verbose (bool, optional): display instances where no data was found for a particular player. Defaults to False.

    Returns:
        float: _description_
    """
    player_stats = dataframe.loc[(dataframe[player_name_col] == player_name) & (dataframe[year_name_col] == year)]

    # the pandemic messed up some of the players due to COVID opt-outs or some players had injuries, if that is the case, we can try looking at a year before the provided date
    if player_stats.empty:
        player_stats = dataframe.loc[(dataframe[player_name_col] == player_name) & (dataframe[year_name_col] == year - 1)]

    
    # Filter by additional parameters if desired
    # for col, val in args:
    #     player_stats = player_stats.loc[player_stats[col] == val]
    
    # Convert to array and grab the value if possible
    if len(player_stats) == 1:
        return player_stats[col_name].to_numpy()[0]
    else:
        if verbose:
            print(f'No data for {player_name} for {col_name} in year {year}')
        return None

# %%
receiving_stats
# Out:
# stat_type  player_id            player  season  LONG  REC   TD    YDS   YPR
# 0             102597       Will Rogers    2022  13.0  1.0  0.0   13.0  13.0
# 1             107494      Trey Sanders    2020   0.0  1.0  0.0   -2.0  -2.0
# 2             107494      Trey Sanders    2021  36.0  6.0  0.0   55.0   9.2
# 3             107494      Trey Sanders    2022  10.0  2.0  0.0   13.0   6.5
# 4             107494      Trey Sanders    2023   8.0  5.0  0.0   20.0   4.0
# ...              ...               ...     ...   ...  ...  ...    ...   ...
# 20637        5243750         Tj Holmes    2024   8.0  1.0  0.0    8.0   8.0
# 20638        5243771       Carlos Mann    2024  21.0  2.0  0.0   30.0  15.0
# 20639        5245626  Brennen Benedict    2024   6.0  1.0  0.0    6.0   6.0
# 20640        5245627           Cj Broy    2024  61.0  9.0  2.0  143.0  15.9
# 20641        5257510   Kenneth Law Jr.    2024  11.0  2.0  0.0   19.0   9.5
#
# [20642 rows x 8 columns]

# %%
rows = []

# In order to make the most high-quality predictions possible, I am only going to focus on players that I have RAS scores as that is my smallest dataset for and then get college data from their previous data from along with their more advanced metrics

df: pd.DataFrame

for player, year, RAS in RAS_parsed[['Name', 'Year', 'RAS']].to_numpy():
    # print(player, year)
    row = {
        'player_name': player,
        'headshot_url': get_val(player, 'headshot_url', nfl_data, year, 'season', 'player_name'),
        'receptions': get_val(player, 'REC', receiving_stats, year - 1, 'season', 'player'),
        'yards': get_val(player, 'YDS', receiving_stats, year - 1, 'season', 'player'),
        'touchdowns': get_val(player, 'TD', receiving_stats, year - 1, 'season', 'player'),
        'yards_per_reception': get_val(player, 'YPR', receiving_stats, year - 1, 'season', 'player'),
        'average_passing_downs_ppa': get_val(player, 'average_passing_downs_ppa', player_predicted_points_combined, year - 1, 'season', 'name'),
        'average_standard_downs_ppa': get_val(player, 'average_standard_downs_ppa', player_predicted_points_combined, year - 1, 'season', 'name'),
        'average_third_down_ppa': get_val(player, 'average_third_down_ppa', player_predicted_points_combined, year - 1, 'season', 'name'),
        'height': get_val(player, 'height', combine_data, year, 'year', 'name'),
        'weight': get_val(player, 'weight', combine_data, year, 'year', 'name'),
        'forty': get_val(player, 'forty', combine_data, year, 'year', 'name'),
        'RAS': RAS,
    }
    rows.append(row)

df: pd.DataFrame = pd.DataFrame(rows)

# %%
df
# Out:
#              player_name                                       headshot_url  \
# 0        Adonai Mitchell  https://static.www.nfl.com/image/upload/f_auto...
# 1       Christian Watson  https://static.www.nfl.com/image/private/f_aut...
# 2         Andrei Iosivas  https://static.www.nfl.com/image/private/f_aut...
# 3           Dareke Young  https://static.www.nfl.com/image/private/f_aut...
# 4            Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# ..                   ...                                                ...
# 117  Montrell Washington  https://static.www.nfl.com/image/private/f_aut...
# 118         Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 119           David Bell  https://static.www.nfl.com/image/private/f_aut...
# 120         Dazz Newsome  https://static.www.nfl.com/image/private/f_aut...
# 121      Demetric Felton  https://static.www.nfl.com/image/private/f_aut...
#
#      receptions   yards  touchdowns  yards_per_reception  \
# 0          55.0   845.0        11.0                 15.4
# 1           NaN     NaN         NaN                  NaN
# 2          66.0   943.0         7.0                 14.3
# 3           NaN     NaN         NaN                  NaN
# 4          92.0  1640.0        13.0                 17.8
# ..          ...     ...         ...                  ...
# 117        10.0   124.0         1.0                 12.4
# 118        42.0   531.0         5.0                 12.6
# 119        93.0  1286.0         6.0                 13.8
# 120        54.0   684.0         6.0                 12.7
# 121        22.0   159.0         3.0                  7.2
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 0                        1.689                       0.673
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                        1.407                       1.068
# ..                         ...                         ...
# 117                        NaN                         NaN
# 118                      0.887                       0.442
# 119                      1.306                       0.741
# 120                      1.448                       0.854
# 121                      0.603                       0.212
#
#      average_third_down_ppa  height  weight  forty   RAS
# 0                     2.063   74.25   205.0   4.34  9.99
# 1                       NaN   76.13   208.0   4.36  9.96
# 2                       NaN   75.13   205.0   4.43  9.96
# 3                       NaN     NaN     NaN    NaN  9.93
# 4                     1.862   74.88   212.0   4.45  9.92
# ..                      ...     ...     ...    ...   ...
# 117                     NaN   68.88   176.0   4.48  4.32
# 118                   0.910   68.38   165.0   4.36  4.29
# 119                   1.518   72.88   212.0   4.68  3.98
# 120                   1.425   70.13   190.0   4.59  2.13
# 121                   1.051   68.62   189.0   4.59  0.87
#
# [122 rows x 13 columns]

# %%
# Drop columns where more than 70% of values are null
df = df[df.isnull().mean(axis = 1) < .3]

df
# Out:
#              player_name                                       headshot_url  \
# 0        Adonai Mitchell  https://static.www.nfl.com/image/upload/f_auto...
# 2         Andrei Iosivas  https://static.www.nfl.com/image/private/f_aut...
# 4            Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# 5         Ricky Pearsall  https://static.www.nfl.com/image/upload/f_auto...
# 6         Xavier Legette  https://static.www.nfl.com/image/upload/f_auto...
# ..                   ...                                                ...
# 117  Montrell Washington  https://static.www.nfl.com/image/private/f_aut...
# 118         Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 119           David Bell  https://static.www.nfl.com/image/private/f_aut...
# 120         Dazz Newsome  https://static.www.nfl.com/image/private/f_aut...
# 121      Demetric Felton  https://static.www.nfl.com/image/private/f_aut...
#
#      receptions   yards  touchdowns  yards_per_reception  \
# 0          55.0   845.0        11.0                 15.4
# 2          66.0   943.0         7.0                 14.3
# 4          92.0  1640.0        13.0                 17.8
# 5          64.0   970.0         4.0                 15.2
# 6          71.0  1255.0         7.0                 17.7
# ..          ...     ...         ...                  ...
# 117        10.0   124.0         1.0                 12.4
# 118        42.0   531.0         5.0                 12.6
# 119        93.0  1286.0         6.0                 13.8
# 120        54.0   684.0         6.0                 12.7
# 121        22.0   159.0         3.0                  7.2
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 0                        1.689                       0.673
# 2                          NaN                         NaN
# 4                        1.407                       1.068
# 5                        1.072                       1.133
# 6                        1.249                       1.206
# ..                         ...                         ...
# 117                        NaN                         NaN
# 118                      0.887                       0.442
# 119                      1.306                       0.741
# 120                      1.448                       0.854
# 121                      0.603                       0.212
#
#      average_third_down_ppa  height  weight  forty   RAS
# 0                     2.063   74.25   205.0   4.34  9.99
# 2                       NaN   75.13   205.0   4.43  9.96
# 4                     1.862   74.88   212.0   4.45  9.92
# 5                     1.248   73.00   189.0   4.41  9.91
# 6                     1.853   73.00   221.0   4.39  9.90
# ..                      ...     ...     ...    ...   ...
# 117                     NaN   68.88   176.0   4.48  4.32
# 118                   0.910   68.38   165.0   4.36  4.29
# 119                   1.518   72.88   212.0   4.68  3.98
# 120                   1.425   70.13   190.0   4.59  2.13
# 121                   1.051   68.62   189.0   4.59  0.87
#
# [114 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# player_name                   0
# headshot_url                  7
# receptions                    0
# yards                         0
# touchdowns                    0
# yards_per_reception           0
# average_passing_downs_ppa     3
# average_standard_downs_ppa    3
# average_third_down_ppa        3
# height                        0
# weight                        0
# forty                         0
# RAS                           0
# dtype: int64

# %%
# Very few values are missing, so we can just impute them with the median for the column
df['average_passing_downs_ppa'].fillna(df['average_passing_downs_ppa'].median(), inplace=True)
df['average_standard_downs_ppa'].fillna(df['average_standard_downs_ppa'].median(), inplace=True)
df['average_third_down_ppa'].fillna(df['average_third_down_ppa'].median(), inplace=True)

df
# Out:
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2432966232.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2432966232.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2432966232.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              player_name                                       headshot_url  \
# 0        Adonai Mitchell  https://static.www.nfl.com/image/upload/f_auto...
# 2         Andrei Iosivas  https://static.www.nfl.com/image/private/f_aut...
# 4            Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# 5         Ricky Pearsall  https://static.www.nfl.com/image/upload/f_auto...
# 6         Xavier Legette  https://static.www.nfl.com/image/upload/f_auto...
# ..                   ...                                                ...
# 117  Montrell Washington  https://static.www.nfl.com/image/private/f_aut...
# 118         Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 119           David Bell  https://static.www.nfl.com/image/private/f_aut...
# 120         Dazz Newsome  https://static.www.nfl.com/image/private/f_aut...
# 121      Demetric Felton  https://static.www.nfl.com/image/private/f_aut...
#
#      receptions   yards  touchdowns  yards_per_reception  \
# 0          55.0   845.0        11.0                 15.4
# 2          66.0   943.0         7.0                 14.3
# 4          92.0  1640.0        13.0                 17.8
# 5          64.0   970.0         4.0                 15.2
# 6          71.0  1255.0         7.0                 17.7
# ..          ...     ...         ...                  ...
# 117        10.0   124.0         1.0                 12.4
# 118        42.0   531.0         5.0                 12.6
# 119        93.0  1286.0         6.0                 13.8
# 120        54.0   684.0         6.0                 12.7
# 121        22.0   159.0         3.0                  7.2
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 0                        1.689                       0.673
# 2                        1.236                       0.841
# 4                        1.407                       1.068
# 5                        1.072                       1.133
# 6                        1.249                       1.206
# ..                         ...                         ...
# 117                      1.236                       0.841
# 118                      0.887                       0.442
# 119                      1.306                       0.741
# 120                      1.448                       0.854
# 121                      0.603                       0.212
#
#      average_third_down_ppa  height  weight  forty   RAS
# 0                     2.063   74.25   205.0   4.34  9.99
# 2                     1.425   75.13   205.0   4.43  9.96
# 4                     1.862   74.88   212.0   4.45  9.92
# 5                     1.248   73.00   189.0   4.41  9.91
# 6                     1.853   73.00   221.0   4.39  9.90
# ..                      ...     ...     ...    ...   ...
# 117                   1.425   68.88   176.0   4.48  4.32
# 118                   0.910   68.38   165.0   4.36  4.29
# 119                   1.518   72.88   212.0   4.68  3.98
# 120                   1.425   70.13   190.0   4.59  2.13
# 121                   1.051   68.62   189.0   4.59  0.87
#
# [114 rows x 13 columns]

# %%
# Time to repeat the same process for the players that are about to get drafted

rows = []

for player, year, RAS in RAS_2025_receivers[['Name', 'Year', 'RAS']].to_numpy():
    # print(player, year)
    row = {
        'player_name': player,
        'receptions': get_val(player, 'REC', receiving_stats, year - 1, 'season', 'player'),
        'yards': get_val(player, 'YDS', receiving_stats, year - 1, 'season', 'player'),
        'touchdowns': get_val(player, 'TD', receiving_stats, year - 1, 'season', 'player'),
        'yards_per_reception': get_val(player, 'YPR', receiving_stats, year - 1, 'season', 'player'),
        'average_passing_downs_ppa': get_val(player, 'average_passing_downs_ppa', player_predicted_points_combined, year - 1, 'season', 'name'),
        'average_standard_downs_ppa': get_val(player, 'average_standard_downs_ppa', player_predicted_points_combined, year - 1, 'season', 'name'),
        'average_third_down_ppa': get_val(player, 'average_third_down_ppa', player_predicted_points_combined, year - 1, 'season', 'name'),
        'height': get_val(player, 'height', combine_data_2025, year, 'year', 'name'),
        'weight': get_val(player, 'weight', combine_data_2025, year, 'year', 'name'),
        'forty': get_val(player, 'forty', combine_data_2025, year, 'year', 'name'),
        'RAS': RAS,
    }
    rows.append(row)

df_25_prospects: pd.DataFrame = pd.DataFrame(rows)

# %%
df_25_prospects
# Out:
#          player_name  receptions  yards  touchdowns  yards_per_reception  \
# 0      Landon Parker        27.0  350.0         0.0                 13.0
# 1       Isaac TeSlaa         NaN    NaN         NaN                  NaN
# 2       Isaiah Neyor        34.0  455.0         5.0                 13.4
# 3          Sam Brown        36.0  509.0         2.0                 14.1
# 4    Dont'e Thornton         NaN    NaN         NaN                  NaN
# ..               ...         ...    ...         ...                  ...
# 409    Steven Alaniz         NaN    NaN         NaN                  NaN
# 410         Ty Wiley         NaN    NaN         NaN                  NaN
# 411    Terez Traynor         2.0   18.0         0.0                  9.0
# 412      Dejuan Bell         NaN    NaN         NaN                  NaN
# 413        Beau Burk         NaN    NaN         NaN                  NaN
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 0                        1.608                       0.777
# 1                          NaN                         NaN
# 2                        1.866                       1.155
# 3                        0.803                       1.436
# 4                          NaN                         NaN
# ..                         ...                         ...
# 409                        NaN                         NaN
# 410                        NaN                         NaN
# 411                      1.521                       0.358
# 412                        NaN                         NaN
# 413                        NaN                         NaN
#
#      average_third_down_ppa  height  weight  forty   RAS
# 0                     2.194     NaN     NaN    NaN  9.97
# 1                       NaN   75.62   214.0   4.43  9.93
# 2                     1.982   76.25   218.0   4.40  9.90
# 3                     0.938     NaN     NaN    NaN  9.90
# 4                       NaN     NaN     NaN    NaN  9.85
# ..                      ...     ...     ...    ...   ...
# 409                     NaN     NaN     NaN    NaN  0.12
# 410                     NaN     NaN     NaN    NaN  0.10
# 411                   1.521     NaN     NaN    NaN  0.10
# 412                     NaN     NaN     NaN    NaN  0.07
# 413                     NaN     NaN     NaN    NaN  0.07
#
# [414 rows x 12 columns]

# %%
df_25_prospects = df_25_prospects[df_25_prospects.isnull().mean(axis = 1) < .2]

df_25_prospects
# Out:
#           player_name  receptions   yards  touchdowns  yards_per_reception  \
# 2        Isaiah Neyor        34.0   455.0         5.0                 13.4
# 5         Tory Horton        25.0   331.0         1.0                 13.2
# 6         Jaylin Noel        81.0  1194.0         8.0                 14.7
# 8        Emeka Egbuka        81.0  1011.0        10.0                 12.5
# 9        Chimere Dike        42.0   783.0         2.0                 18.6
# 10      Elic Ayomanor        63.0   831.0         6.0                 13.2
# 11     Jayden Higgins        87.0  1183.0         9.0                 13.6
# 14        Jaylin Lane        38.0   466.0         2.0                 12.3
# 18          Jack Bech        62.0  1034.0         9.0                 16.7
# 22     Elijhah Badger        39.0   806.0         4.0                 20.7
# 24         Tre Harris        61.0  1063.0         7.0                 17.4
# 25        Arian Smith        48.0   817.0         4.0                 17.0
# 26         Tai Felton        96.0  1124.0         9.0                 11.7
# 28      Beaux Collins        41.0   490.0         3.0                 12.0
# 31       Jalen Royals        55.0   834.0         6.0                 15.2
# 36     Jordan Watkins        49.0   906.0         9.0                 18.5
# 42   Andrew Armstrong        78.0  1140.0         1.0                 14.6
# 48     Da'Quan Felton        32.0   360.0         2.0                 11.3
# 62      Kaden Prather        56.0   624.0         4.0                 11.1
# 77        Tez Johnson        83.0   898.0        10.0                 10.8
# 79         Roc Taylor        66.0   950.0         2.0                 14.4
# 82     Daniel Jackson        75.0   863.0         4.0                 11.5
# 99     Dominic Lovett        59.0   607.0         6.0                 10.3
# 116  Konata Mumpfield        52.0   813.0         5.0                 15.6
# 133         Nick Nash       104.0  1382.0        16.0                 13.3
# 155   Traeshon Holden        45.0   718.0         5.0                 16.0
# 209       Isaiah Bond        34.0   540.0         5.0                 15.9
# 213   Ja'Corey Brooks        61.0  1013.0         9.0                 16.6
# 219        Josh Kelly        89.0  1023.0         5.0                 11.5
# 222   Xavier Restrepo        69.0  1127.0        11.0                 16.3
# 225       Kobe Hudson        47.0   770.0         4.0                 16.4
# 235    Jacolby George        53.0   752.0         8.0                 14.2
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 2                        1.866                       1.155
# 5                        1.473                       0.449
# 6                        1.187                       1.034
# 8                        1.136                       0.974
# 9                        1.074                       0.909
# 10                       1.388                       0.951
# 11                       1.575                       0.966
# 14                       1.290                       0.767
# 18                       1.521                       0.992
# 22                       1.396                       0.817
# 24                       0.975                       1.460
# 25                       1.112                       1.043
# 26                       1.572                       0.836
# 28                       0.966                       0.844
# 31                       2.413                       1.244
# 36                       2.208                       0.759
# 42                       1.247                       0.952
# 48                       0.974                       0.656
# 62                       1.066                       0.787
# 77                       2.018                       0.686
# 79                       1.473                       0.836
# 82                       0.869                       1.140
# 99                       0.886                       0.385
# 116                      1.448                       1.371
# 133                      1.433                       1.446
# 155                      1.970                       1.001
# 209                      1.928                       0.909
# 213                      2.671                       0.827
# 219                      1.183                       1.094
# 222                      1.947                       1.290
# 225                      1.075                       1.143
# 235                      2.166                       0.860
#
#      average_third_down_ppa  height  weight  forty   RAS
# 2                     1.982   76.25   218.0   4.40  9.90
# 5                     1.130   74.50   196.0   4.41  9.83
# 6                     1.133   70.25   194.0   4.39  9.75
# 8                     0.898   72.88   202.0    NaN  9.72
# 9                     1.488   72.62   196.0   4.34  9.72
# 10                    1.732   73.75   206.0   4.44  9.71
# 11                    1.934   76.12   214.0   4.47  9.63
# 14                    1.024   69.75   191.0   4.34  9.56
# 18                    1.555   73.25   214.0    NaN  9.51
# 22                    1.354   73.38   200.0   4.43  9.32
# 24                    1.048   74.38   205.0   4.54  9.23
# 25                    1.781   72.12   179.0   4.36  9.20
# 26                    1.336   73.12   183.0   4.37  9.20
# 28                    0.745   75.00   201.0    NaN  9.09
# 31                    2.124   72.00   205.0   4.42  9.01
# 36                    0.891   71.25   196.0   4.37  8.79
# 42                    1.279   75.75   202.0   4.51  8.58
# 48                    1.895   76.25   213.0   4.50  8.30
# 62                    1.138   75.50   204.0   4.46  7.68
# 77                    1.944   69.88   154.0   4.51  7.31
# 79                    2.110   73.88   213.0   4.49  7.23
# 82                    1.162   70.75   193.0    NaN  7.14
# 99                    0.644   70.00   185.0   4.40  6.67
# 116                   1.887   71.38   186.0   4.59  6.35
# 133                   1.415   74.50   203.0   4.57  6.00
# 155                   2.548   74.12   205.0   4.57  5.42
# 209                   1.610   70.62   180.0   4.39  4.23
# 213                   2.769   74.00   184.0    NaN  4.15
# 219                   1.490   72.62   186.0   4.70  3.98
# 222                   1.874   69.88   209.0    NaN  3.96
# 225                   0.846   72.75   193.0   4.57  3.94
# 235                   1.976   71.00   172.0    NaN  3.75

# %%
df_25_prospects['forty'].fillna(df['forty'].median(), inplace=True)

df_25_prospects
# Out:
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2597022336.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           player_name  receptions   yards  touchdowns  yards_per_reception  \
# 2        Isaiah Neyor        34.0   455.0         5.0                 13.4
# 5         Tory Horton        25.0   331.0         1.0                 13.2
# 6         Jaylin Noel        81.0  1194.0         8.0                 14.7
# 8        Emeka Egbuka        81.0  1011.0        10.0                 12.5
# 9        Chimere Dike        42.0   783.0         2.0                 18.6
# 10      Elic Ayomanor        63.0   831.0         6.0                 13.2
# 11     Jayden Higgins        87.0  1183.0         9.0                 13.6
# 14        Jaylin Lane        38.0   466.0         2.0                 12.3
# 18          Jack Bech        62.0  1034.0         9.0                 16.7
# 22     Elijhah Badger        39.0   806.0         4.0                 20.7
# 24         Tre Harris        61.0  1063.0         7.0                 17.4
# 25        Arian Smith        48.0   817.0         4.0                 17.0
# 26         Tai Felton        96.0  1124.0         9.0                 11.7
# 28      Beaux Collins        41.0   490.0         3.0                 12.0
# 31       Jalen Royals        55.0   834.0         6.0                 15.2
# 36     Jordan Watkins        49.0   906.0         9.0                 18.5
# 42   Andrew Armstrong        78.0  1140.0         1.0                 14.6
# 48     Da'Quan Felton        32.0   360.0         2.0                 11.3
# 62      Kaden Prather        56.0   624.0         4.0                 11.1
# 77        Tez Johnson        83.0   898.0        10.0                 10.8
# 79         Roc Taylor        66.0   950.0         2.0                 14.4
# 82     Daniel Jackson        75.0   863.0         4.0                 11.5
# 99     Dominic Lovett        59.0   607.0         6.0                 10.3
# 116  Konata Mumpfield        52.0   813.0         5.0                 15.6
# 133         Nick Nash       104.0  1382.0        16.0                 13.3
# 155   Traeshon Holden        45.0   718.0         5.0                 16.0
# 209       Isaiah Bond        34.0   540.0         5.0                 15.9
# 213   Ja'Corey Brooks        61.0  1013.0         9.0                 16.6
# 219        Josh Kelly        89.0  1023.0         5.0                 11.5
# 222   Xavier Restrepo        69.0  1127.0        11.0                 16.3
# 225       Kobe Hudson        47.0   770.0         4.0                 16.4
# 235    Jacolby George        53.0   752.0         8.0                 14.2
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 2                        1.866                       1.155
# 5                        1.473                       0.449
# 6                        1.187                       1.034
# 8                        1.136                       0.974
# 9                        1.074                       0.909
# 10                       1.388                       0.951
# 11                       1.575                       0.966
# 14                       1.290                       0.767
# 18                       1.521                       0.992
# 22                       1.396                       0.817
# 24                       0.975                       1.460
# 25                       1.112                       1.043
# 26                       1.572                       0.836
# 28                       0.966                       0.844
# 31                       2.413                       1.244
# 36                       2.208                       0.759
# 42                       1.247                       0.952
# 48                       0.974                       0.656
# 62                       1.066                       0.787
# 77                       2.018                       0.686
# 79                       1.473                       0.836
# 82                       0.869                       1.140
# 99                       0.886                       0.385
# 116                      1.448                       1.371
# 133                      1.433                       1.446
# 155                      1.970                       1.001
# 209                      1.928                       0.909
# 213                      2.671                       0.827
# 219                      1.183                       1.094
# 222                      1.947                       1.290
# 225                      1.075                       1.143
# 235                      2.166                       0.860
#
#      average_third_down_ppa  height  weight  forty   RAS
# 2                     1.982   76.25   218.0   4.40  9.90
# 5                     1.130   74.50   196.0   4.41  9.83
# 6                     1.133   70.25   194.0   4.39  9.75
# 8                     0.898   72.88   202.0   4.46  9.72
# 9                     1.488   72.62   196.0   4.34  9.72
# 10                    1.732   73.75   206.0   4.44  9.71
# 11                    1.934   76.12   214.0   4.47  9.63
# 14                    1.024   69.75   191.0   4.34  9.56
# 18                    1.555   73.25   214.0   4.46  9.51
# 22                    1.354   73.38   200.0   4.43  9.32
# 24                    1.048   74.38   205.0   4.54  9.23
# 25                    1.781   72.12   179.0   4.36  9.20
# 26                    1.336   73.12   183.0   4.37  9.20
# 28                    0.745   75.00   201.0   4.46  9.09
# 31                    2.124   72.00   205.0   4.42  9.01
# 36                    0.891   71.25   196.0   4.37  8.79
# 42                    1.279   75.75   202.0   4.51  8.58
# 48                    1.895   76.25   213.0   4.50  8.30
# 62                    1.138   75.50   204.0   4.46  7.68
# 77                    1.944   69.88   154.0   4.51  7.31
# 79                    2.110   73.88   213.0   4.49  7.23
# 82                    1.162   70.75   193.0   4.46  7.14
# 99                    0.644   70.00   185.0   4.40  6.67
# 116                   1.887   71.38   186.0   4.59  6.35
# 133                   1.415   74.50   203.0   4.57  6.00
# 155                   2.548   74.12   205.0   4.57  5.42
# 209                   1.610   70.62   180.0   4.39  4.23
# 213                   2.769   74.00   184.0   4.46  4.15
# 219                   1.490   72.62   186.0   4.70  3.98
# 222                   1.874   69.88   209.0   4.46  3.96
# 225                   0.846   72.75   193.0   4.57  3.94
# 235                   1.976   71.00   172.0   4.46  3.75

# %% [markdown]
# # II. Data Understanding / Visualization

# %%
def download_headshots(names: pd.Series, headshots: pd.Series, filepath: str, download: bool = False) -> list[str]:
    """Download headshots of players and save to filepath

    Args:
        names (pd.Series): names of the players; will serve as filepath (i.e. "Tom Brady" -> "tom-brady.png")
        headshots (pd.Series): headshot urls
        filepath (str): filepath to save the headshots to
        download (bool): to just get an array of file paths if the headshots have already been downloaded. Defaults to False
    
    Returns: 
        list[str]: list of all filepaths
    """
    img_filepaths: list[str] = []
    for name, headshot in zip(names, headshots):
        path = f"{filepath}{name.lower().replace(' ', '-')}.png"
        img_filepaths.append(path)
        if download:
            img = requests.get(headshot).content
            with open(path, 'wb') as handler:
                handler.write(img)
            print(f'Saved the headshot of {name} to {path}')
    
    return img_filepaths

# %%
puka_vs_mingo_combine: pd.DataFrame = combine_data.loc[combine_data['name'].isin(['Jonathan Mingo', 'Puka Nacua'])].drop(columns = ['Unnamed: 0','year', 'pos']).reset_index()
names_with_headshots: pd.DataFrame = nfl.import_seasonal_rosters(years = [2023])[['player_name', 'headshot_url', 'draft_number']]
puka_vs_mingo_headshots_df: pd.DataFrame = names_with_headshots.loc[names_with_headshots['player_name'].isin(['Jonathan Mingo', 'Puka Nacua'])]
puka_vs_mingo_combine['img_filepath'] = download_headshots(puka_vs_mingo_headshots_df['player_name'], puka_vs_mingo_headshots_df['headshot_url'], '../img/nfl_headshots/')
puka_vs_mingo_combine['RAS'] = RAS_parsed.loc[RAS_parsed['Name'].isin(['Jonathan Mingo', 'Puka Nacua']), 'RAS'].to_numpy()
puka_vs_mingo_combine['Draft Position'] = puka_vs_mingo_headshots_df['draft_number'].to_numpy()
puka_vs_mingo_combine
# Out:
#    index            name        college  height  weight  forty  bench  \
# 0    133  Jonathan Mingo    Mississippi   73.75     220   4.46   22.0
# 1    135      Puka Nacua  Brigham Young   73.63     210   4.57   15.0
#
#    vertical  broad jump  shuttle  3-cone  \
# 0      39.5       129.0     4.25    7.04
# 1      33.0       121.0     4.36    7.32
#
#                               img_filepath   RAS  Draft Position
# 0  ../img/nfl_headshots/jonathan-mingo.png  9.87            39.0
# 1      ../img/nfl_headshots/puka-nacua.png  5.18           177.0

# %%
puka_vs_mingo_combine_table: GT = (
    GT(puka_vs_mingo_combine)
    .tab_header(
        title = md('**Jonathan Mingo vs Puka Nacua: Physical and Combine Comparison**'),
    )
    .fmt_image(
        columns = 'img_filepath',
        height = 75,
    )
    .cols_move_to_start(
        columns = 'img_filepath'
    )
    .cols_label(
        img_filepath = ''
    )
    .tab_options(
        table_font_names=system_fonts("industrial")
    )
    .data_color(
        rows = [0,1],
        columns = ['height', 'weight', 'bench', 'vertical', 'broad jump', 'RAS'],
        palette = 'BuPu',
    )
    .data_color(
        rows = [0,1],
        columns = ['forty', 'shuttle', '3-cone', 'Draft Position'],
        palette = 'BuPu',
        reverse = True
    )
    .cols_hide (
        columns = ['index']
    )

)

# puka_vs_mingo_combine_table.save(file = '../img/puka_vs_mingo_combine_table.png', scale = 6, web_driver = 'firefox')

# %% [markdown]
# ![Jonathan Mingo vs Puka Nacua in Combine and Physical Stats](../img/puka_vs_mingo_combine_table.png)

# %%
puka_vs_mingo_stats: pd.DataFrame = player_predicted_points_combined.loc[(player_predicted_points_combined['name'].isin(['Jonathan Mingo', 'Puka Nacua'])) & (player_predicted_points_combined['season'] == 2022)][['name','average_passing_downs_ppa', 'average_standard_downs_ppa', 'average_third_down_ppa', 'average_first_down_ppa', 'average_second_down_ppa', 'average_all_ppa']].reset_index()

puka_vs_mingo_stats['img_filepath'] = download_headshots(puka_vs_mingo_headshots_df['player_name'], puka_vs_mingo_headshots_df['headshot_url'], '../img/nfl_headshots/')

puka_vs_mingo_stats
# Out:
#    index            name  average_passing_downs_ppa  \
# 0   9308  Jonathan Mingo                      0.182
# 1   9386      Puka Nacua                      0.958
#
#    average_standard_downs_ppa  average_third_down_ppa  average_first_down_ppa  \
# 0                       1.173                   0.368                   1.318
# 1                       1.032                   1.256                   0.976
#
#    average_second_down_ppa  average_all_ppa  \
# 0                    0.218            0.955
# 1                    0.831            1.012
#
#                               img_filepath
# 0  ../img/nfl_headshots/jonathan-mingo.png
# 1      ../img/nfl_headshots/puka-nacua.png

# %%
puka_vs_mingo_stats_table: GT = (
    GT(puka_vs_mingo_stats)
    .tab_header(
        title = md('**Jonathan Mingo vs Puka Nacua: Final Season Statistical Comparison**'),
        subtitle = md('*All Metrics are Average PPA in that scenario*')
    )
    .fmt_image(
        columns = 'img_filepath',
        height = 75,
    )
    .cols_move_to_start(
        columns = 'img_filepath'
    )
    .cols_label(
        img_filepath = '',
        average_passing_downs_ppa = 'Passing Downs',
        average_standard_downs_ppa = 'Standard Downs',
        average_third_down_ppa = '3rd Down',
        average_first_down_ppa = '1st Down',
        average_second_down_ppa = '2nd Down',
        average_all_ppa = 'Overall'
    )
    .data_color(
        columns = ['average_passing_downs_ppa', 'average_standard_downs_ppa', 'average_third_down_ppa', 'average_first_down_ppa', 'average_second_down_ppa', 'average_all_ppa'],
        palette = 'BuPu'
    )
    .tab_options(
        table_font_names=system_fonts("industrial")
    )
    .cols_hide(
        columns = ['index']
    )
)

# puka_vs_mingo_stats_table.save(file = '../img/puka_vs_mingo_stats_table.png', scale = 6, web_driver = 'firefox')

# %% [markdown]
# ![Jonathan Mingo vs Puka Nacua in Final College Season Stats](../img/puka_vs_mingo_stats_table.png)

# %% [markdown]
# # III. Clustering and Modeling our Data

# %%
# First, we likely need to scale our data 
# Keep player_name and headshot_url separate, scale all numeric features
scaler: StandardScaler =  StandardScaler()
features_scaled: np.ndarray[float, float] = scaler.fit_transform(df.iloc[:, 2:])

# Create a DataFrame with the scaled features
df_scaled = pd.DataFrame(features_scaled, columns=df.columns[2:])

# Add player names back as the first column
df_scaled.insert(0, 'headshot_url', df['headshot_url'].reset_index(drop = True))
df_scaled.insert(0, 'player_name', df['player_name'].reset_index(drop = True))

df_scaled
# Out:
#              player_name                                       headshot_url  \
# 0        Adonai Mitchell  https://static.www.nfl.com/image/upload/f_auto...
# 1         Andrei Iosivas  https://static.www.nfl.com/image/private/f_aut...
# 2            Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# 3         Ricky Pearsall  https://static.www.nfl.com/image/upload/f_auto...
# 4         Xavier Legette  https://static.www.nfl.com/image/upload/f_auto...
# ..                   ...                                                ...
# 109  Montrell Washington  https://static.www.nfl.com/image/private/f_aut...
# 110         Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 111           David Bell  https://static.www.nfl.com/image/private/f_aut...
# 112         Dazz Newsome  https://static.www.nfl.com/image/private/f_aut...
# 113      Demetric Felton  https://static.www.nfl.com/image/private/f_aut...
#
#      receptions     yards  touchdowns  yards_per_reception  \
# 0     -0.030432  0.053605    0.982966             0.172620
# 1      0.452626  0.336226    0.023153            -0.196775
# 2      1.594399  2.346296    1.462873             0.978574
# 3      0.364797  0.414091   -0.696706             0.105457
# 4      0.672198  1.235999    0.023153             0.944993
# ..          ...       ...         ...                  ...
# 109   -2.006577 -2.025679   -1.416566            -0.834822
# 110   -0.601318 -0.851936   -0.456753            -0.767659
# 111    1.638313  1.325400   -0.216800            -0.364682
# 112   -0.074346 -0.410701   -0.216800            -0.734078
# 113   -1.479605 -1.924742   -0.936659            -2.581055
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 0                     0.908736                   -0.541970
# 1                     0.066130                   -0.075922
# 2                     0.384200                    0.553796
# 3                    -0.238919                    0.734112
# 4                     0.090311                    0.936620
# ..                         ...                         ...
# 109                   0.066130                   -0.075922
# 110                  -0.583030                   -1.182784
# 111                   0.196334                   -0.353331
# 112                   0.460462                   -0.039859
# 113                  -1.111286                   -1.820825
#
#      average_third_down_ppa    height    weight     forty       RAS
# 0                  1.167761  0.887910  0.623008 -1.396796  1.202541
# 1                  0.085598  1.269029  0.623008 -0.351491  1.185513
# 2                  0.826828  1.160757  1.092470 -0.119201  1.162810
# 3                 -0.214626  0.346548 -0.450048 -0.583781  1.157134
# 4                  0.811563  0.346548  1.696064 -0.816071  1.151458
# ..                      ...       ...       ...       ...       ...
# 109                0.085598 -1.437783 -1.321906  0.229233 -2.015686
# 110               -0.787935 -1.654328 -2.059632 -1.164506 -2.032714
# 111                0.243342  0.294577  1.092470  2.552133 -2.208666
# 112                0.085598 -0.896420 -0.382982  1.506828 -3.258705
# 113               -0.548774 -1.550386 -0.450048  1.506828 -3.973866
#
# [114 rows x 13 columns]

# %%
kmeans = KMeans(n_clusters = 4).fit(df_scaled.iloc[:, 2:])
df['cluster'] = kmeans.labels_

df
# Out:
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2521417668.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              player_name                                       headshot_url  \
# 0        Adonai Mitchell  https://static.www.nfl.com/image/upload/f_auto...
# 2         Andrei Iosivas  https://static.www.nfl.com/image/private/f_aut...
# 4            Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# 5         Ricky Pearsall  https://static.www.nfl.com/image/upload/f_auto...
# 6         Xavier Legette  https://static.www.nfl.com/image/upload/f_auto...
# ..                   ...                                                ...
# 117  Montrell Washington  https://static.www.nfl.com/image/private/f_aut...
# 118         Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 119           David Bell  https://static.www.nfl.com/image/private/f_aut...
# 120         Dazz Newsome  https://static.www.nfl.com/image/private/f_aut...
# 121      Demetric Felton  https://static.www.nfl.com/image/private/f_aut...
#
#      receptions   yards  touchdowns  yards_per_reception  \
# 0          55.0   845.0        11.0                 15.4
# 2          66.0   943.0         7.0                 14.3
# 4          92.0  1640.0        13.0                 17.8
# 5          64.0   970.0         4.0                 15.2
# 6          71.0  1255.0         7.0                 17.7
# ..          ...     ...         ...                  ...
# 117        10.0   124.0         1.0                 12.4
# 118        42.0   531.0         5.0                 12.6
# 119        93.0  1286.0         6.0                 13.8
# 120        54.0   684.0         6.0                 12.7
# 121        22.0   159.0         3.0                  7.2
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 0                        1.689                       0.673
# 2                        1.236                       0.841
# 4                        1.407                       1.068
# 5                        1.072                       1.133
# 6                        1.249                       1.206
# ..                         ...                         ...
# 117                      1.236                       0.841
# 118                      0.887                       0.442
# 119                      1.306                       0.741
# 120                      1.448                       0.854
# 121                      0.603                       0.212
#
#      average_third_down_ppa  height  weight  forty   RAS  cluster
# 0                     2.063   74.25   205.0   4.34  9.99        0
# 2                     1.425   75.13   205.0   4.43  9.96        0
# 4                     1.862   74.88   212.0   4.45  9.92        0
# 5                     1.248   73.00   189.0   4.41  9.91        0
# 6                     1.853   73.00   221.0   4.39  9.90        0
# ..                      ...     ...     ...    ...   ...      ...
# 117                   1.425   68.88   176.0   4.48  4.32        1
# 118                   0.910   68.38   165.0   4.36  4.29        1
# 119                   1.518   72.88   212.0   4.68  3.98        1
# 120                   1.425   70.13   190.0   4.59  2.13        1
# 121                   1.051   68.62   189.0   4.59  0.87        1
#
# [114 rows x 14 columns]

# %%
pca: PCA = PCA(n_components = 3).fit(df_scaled.iloc[:, 2:])

pca_curr: np.ndarray = pca.transform(df_scaled.iloc[:, 2:])
df['pca1'] = pca_curr[:, 0]
df['pca2'] = pca_curr[:, 1]
df['pca3'] = pca_curr[:, 2]

clusters: px.scatter_3d = px.scatter_3d(
    df, 
    x='pca1', 
    y='pca2', 
    z = 'pca3', 
    color='cluster', 
    hover_name = 'player_name', 
)

# Write scatterplot to HTML so we can display on the website
clusters.write_html(file = '../plotly/NFL_WRs_clusters.html')

# Write clusters to image so we can display in the notebook
# clusters.write_image(file = '../img/NFL_WRs_clusters.png')
# Out:
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2975301980.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2975301980.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\2975301980.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ![NFL Wide Recivers, clustered](../img/NFL_WRs_clusters.png?12)

# %%
new_picks_scaled: np.ndarray = scaler.transform(df_25_prospects.iloc[:, 1:])

new_clusters: np.ndarray = kmeans.predict(new_picks_scaled)

df_25_prospects['cluster'] = new_clusters
# Out:
# c:\Users\ernie\randSchool\2024-2025\ITCS 3162\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but KMeans was fitted with feature names
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\543240814.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_pca = pca.transform(new_picks_scaled)
df_25_prospects['pca1'] = new_pca[:, 0]
df_25_prospects['pca2'] = new_pca[:, 1]
df_25_prospects['pca3'] = new_pca[:, 2]

clusters_new: px.scatter_3d = px.scatter_3d(
    df_25_prospects, 
    x='pca1', 
    y='pca2', 
    z = 'pca3', 
    color='cluster', 
    hover_name = 'player_name', 
)

# Write scatterplot to HTML so we can display on the website
clusters_new.write_html(file = '../plotly/NFL_2025_WRs_clusters.html')

# Write clusters to image so we can display in the notebook
# clusters_new.write_image(file = '../img/NFL_2025_WRs_clusters.png')
# Out:
# c:\Users\ernie\randSchool\2024-2025\ITCS 3162\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning:
#
# X does not have valid feature names, but PCA was fitted with feature names
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\1976998546.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\1976998546.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\1976998546.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# !["2025 NFL Wide Receivers, clustered"](../img/NFL_2025_WRs_clusters.png?12)

# %%
df_with_stats = pd.merge(left = df, right = nfl_data, how = 'left', on = 'player_name').drop_duplicates(subset = ['player_name'], keep = 'first').sort_values(by = 'draft_number').groupby('cluster').head(7)

df_with_stats
# Out:
#             player_name                                     headshot_url_x  \
# 17        Ja'Marr Chase  https://static.www.nfl.com/image/private/f_aut...
# 28         Malik Nabers  https://static.www.nfl.com/image/upload/f_auto...
# 3           Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# 146      Garrett Wilson  https://static.www.nfl.com/image/private/f_aut...
# 104         Chris Olave  https://static.www.nfl.com/image/private/f_aut...
# 207        Jahan Dotson  https://static.www.nfl.com/image/private/f_aut...
# 221       Treylon Burks  https://static.www.nfl.com/image/private/f_aut...
# 124  Jaxon Smith-Njigba  https://static.www.nfl.com/image/private/f_aut...
# 65       Kadarius Toney  https://static.www.nfl.com/image/private/f_aut...
# 89     Quentin Johnston  https://static.www.nfl.com/image/private/f_aut...
# 126         Zay Flowers  https://static.www.nfl.com/image/private/f_aut...
# 16     Brian Thomas Jr.  https://static.www.nfl.com/image/upload/f_auto...
# 219      Jordan Addison  https://static.www.nfl.com/image/private/f_aut...
# 128      Rashod Bateman  https://static.www.nfl.com/image/private/f_aut...
# 43        Xavier Worthy  https://static.www.nfl.com/image/upload/f_auto...
# 4        Ricky Pearsall  https://static.www.nfl.com/image/upload/f_auto...
# 137        Keon Coleman  https://static.www.nfl.com/image/upload/f_auto...
# 11       Jonathan Mingo  https://static.www.nfl.com/image/private/f_aut...
# 44        Rondale Moore  https://static.www.nfl.com/image/private/f_aut...
# 204         Jayden Reed  https://static.www.nfl.com/image/private/f_aut...
# 48       George Pickens  https://static.www.nfl.com/image/private/f_aut...
# 96       Cedric Tillman                                               None
# 227       Amari Rodgers  https://static.www.nfl.com/image/private/f_aut...
# 252          David Bell  https://static.www.nfl.com/image/private/f_aut...
# 171          Tre Tucker  https://static.www.nfl.com/image/private/f_aut...
# 162   Amon-Ra St. Brown  https://static.www.nfl.com/image/private/f_aut...
# 250        Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 182       Erik Ezukanma  https://static.www.nfl.com/image/private/f_aut...
#
#      receptions   yards  touchdowns  yards_per_reception  \
# 17         84.0  1780.0        20.0                 21.2
# 28         89.0  1569.0        14.0                 17.6
# 3          92.0  1640.0        13.0                 17.8
# 146        70.0  1058.0        12.0                 15.1
# 104        65.0   936.0        13.0                 14.4
# 207        91.0  1182.0        12.0                 13.0
# 221        66.0  1104.0        11.0                 16.7
# 124         5.0    43.0         0.0                  8.6
# 65         70.0   984.0        10.0                 14.1
# 89         60.0  1069.0         6.0                 17.8
# 126        78.0  1077.0        12.0                 13.8
# 16         68.0  1177.0        17.0                 17.3
# 219        59.0   875.0         8.0                 14.8
# 128        36.0   472.0         2.0                 13.1
# 43         75.0  1014.0         5.0                 13.5
# 4          64.0   970.0         4.0                 15.2
# 137        50.0   658.0        11.0                 13.2
# 11         51.0   862.0         5.0                 16.9
# 44         35.0   270.0         0.0                  7.7
# 204        55.0   636.0         5.0                 11.6
# 48          5.0   107.0         0.0                 21.4
# 96         37.0   417.0         3.0                 11.3
# 227        77.0  1020.0         7.0                 13.2
# 252        93.0  1286.0         6.0                 13.8
# 171        52.0   672.0         3.0                 12.9
# 162        41.0   478.0         7.0                 11.7
# 250        42.0   531.0         5.0                 12.6
# 182        48.0   705.0         4.0                 14.7
#
#      average_passing_downs_ppa  average_standard_downs_ppa  \
# 17                       1.684                       1.279
# 28                       1.314                       1.103
# 3                        1.407                       1.068
# 146                      1.207                       1.097
# 104                      1.635                       0.666
# 207                      0.816                       0.886
# 221                      1.236                       1.296
# 124                     -0.274                       0.019
# 65                       1.628                       0.675
# 89                       1.208                       0.696
# 126                      1.581                       0.733
# 16                       1.582                       1.682
# 219                      1.078                       0.938
# 128                      1.157                       0.398
# 43                       0.797                       0.582
# 4                        1.072                       1.133
# 137                      0.616                       0.758
# 11                       0.182                       1.173
# 44                       0.147                       0.544
# 204                      0.960                       0.676
# 48                      -0.947                       1.059
# 96                       1.170                       0.502
# 227                      1.002                       0.814
# 252                      1.306                       0.741
# 171                      1.380                       0.482
# 162                      0.776                       0.945
# 250                      0.887                       0.442
# 182                      1.754                       0.751
#
#      average_third_down_ppa  height_x  ...  status_description_abbr  \
# 17                    1.357     72.38  ...                      A01
# 28                    1.278     71.75  ...                      A01
# 3                     1.862     74.88  ...                      A01
# 146                   1.151     71.75  ...                      A01
# 104                   1.850     72.38  ...                      A01
# 207                   1.047     70.63  ...                      A01
# 221                   1.905     73.88  ...                      A01
# 124                  -0.608     72.63  ...                      A01
# 65                    1.952     71.63  ...                      A01
# 89                    1.073     74.75  ...                      A01
# 126                   1.551     69.25  ...                      A01
# 16                    1.843     74.88  ...                      A01
# 219                   1.341     71.13  ...                      A01
# 128                   1.065     72.38  ...                      A01
# 43                    0.105     71.25  ...                      A01
# 4                     1.248     73.00  ...                      A01
# 137                   0.723     75.25  ...                      A01
# 11                    0.368     73.75  ...                      R01
# 44                    0.816     67.00  ...                      A01
# 204                   1.022     70.88  ...                      A01
# 48                    0.535     75.25  ...                      A01
# 96                    1.706     75.38  ...                      A01
# 227                   1.167     69.50  ...                      A01
# 252                   1.518     72.88  ...                      A01
# 171                   1.565     68.63  ...                      A01
# 162                   1.746     71.50  ...                      A01
# 250                   0.910     68.38  ...                      A01
# 182                   2.124     73.88  ...                      A01
#
#      football_name     esb_id  gsis_it_id  \
# 17         Ja'Marr  CHA694469       53434
# 28           Malik  NAB400459       57127
# 3             Rome  ODU426541       57130
# 146        Garrett  WIL691962       54475
# 104          Chris  OLA659325       54476
# 207          Jahan  DOT282798       54481
# 221        Treylon  BUR321327       54483
# 124          Jaxon  SMI829636       55884
# 65        Kadarius  TON593115       53449
# 89         Quentin  JOH823261       55885
# 126            Zay  FLO577002       55886
# 16           Brian  THO419793       57144
# 219         Jordan  ADD491056       55887
# 128         Rashod  BAT103884       53456
# 43          Xavier  WOR741496       57149
# 4            Ricky  PEA307677       57152
# 137           Keon  COL295571       57154
# 11        Jonathan  MIN170999       55904
# 44         Rondale  MOO672093       53478
# 204         Jayden  REE263142       55915
# 48          George  PIC576156       54517
# 96          Cedric  TIL377067       55939
# 227          Amari  ROD342823       53514
# 252          David  BEL269820       54564
# 171            Tre  TUC399910       55965
# 162        Amon-Ra  STB415291       53541
# 250         Derius  DAV263132       55990
# 182           Erik  EZU415291       54590
#
#                                  smart_id  entry_year  rookie_year  \
# 17   32004348-4169-4469-b021-d2c20a7d7cf5      2021.0       2021.0
# 28   32004e41-4240-0459-a77d-033b6932cbbb      2024.0       2024.0
# 3    32004f44-5542-6541-431c-1a51e8792659      2024.0       2024.0
# 146  32005749-4c69-1962-4085-d9c826d8709c      2022.0       2022.0
# 104  32004f4c-4165-9325-c259-01a521202e2f      2022.0       2022.0
# 207  3200444f-5428-2798-d9f2-9e8608edcb8a      2022.0       2022.0
# 221  32004255-5232-1327-f36e-987913d19348      2022.0       2022.0
# 124  3200534d-4982-9636-a18c-5da6fbdaa80c      2023.0       2023.0
# 65   3200544f-4e59-3115-b817-44100e7d8fff      2021.0       2021.0
# 89   32004a4f-4882-3261-dcd8-a43c8f7c5608      2023.0       2023.0
# 126  3200464c-4f57-7002-1160-832e9618f0fd      2023.0       2023.0
# 16   32005448-4f41-9793-7e94-7811f8a76eb2      2024.0       2024.0
# 219  32004144-4449-1056-9ba9-b09766bad478      2023.0       2023.0
# 128  32004241-5410-3884-8ac5-165a4f1f770e      2021.0       2021.0
# 43   3200574f-5274-1496-c9ca-5c4709faa05b      2024.0       2024.0
# 4    32005045-4130-7677-7b9e-0f0ef8659c89      2024.0       2024.0
# 137  3200434f-4c29-5571-54fa-77236b775ae1      2024.0       2024.0
# 11   32004d49-4e17-0999-c137-d684c1d1ab38      2023.0       2023.0
# 44   32004d4f-4f67-2093-7b5b-808e901606a0      2021.0       2021.0
# 204  32005245-4526-3142-e96f-a871c08a1138      2023.0       2023.0
# 48   32005049-4357-6156-653f-e3c2b6d1b9bc      2022.0       2022.0
# 96   32005449-4c37-7067-218b-007e17161edd      2023.0       2023.0
# 227  3200524f-4434-2823-8e97-2d93985ad418      2021.0       2021.0
# 252  32004245-4c26-9820-eec2-961722ae3742      2022.0       2022.0
# 171  32005455-4339-9910-7816-4a6883d99032      2023.0       2023.0
# 162  32005354-4241-5291-a564-57e98d35161d      2021.0       2021.0
# 250  32004441-5626-3132-bab0-4f5a3b5e1671      2023.0       2023.0
# 182  3200455a-5541-5291-fee6-830dca8a2c2a      2022.0       2022.0
#
#      draft_club draft_number   age
# 17          CIN          5.0  21.0
# 28          NYG          6.0  21.0
# 3           CHI          9.0  22.0
# 146         NYJ         10.0  22.0
# 104          NO         11.0  22.0
# 207         WAS         16.0  22.0
# 221         TEN         18.0  22.0
# 124         SEA         20.0  21.0
# 65          NYG         20.0  22.0
# 89          LAC         21.0  21.0
# 126         BAL         22.0  22.0
# 16          JAX         23.0  21.0
# 219         MIN         23.0  21.0
# 128         BAL         27.0  21.0
# 43           KC         28.0  21.0
# 4            SF         31.0  23.0
# 137         BUF         33.0  21.0
# 11          CAR         39.0  22.0
# 44          ARI         49.0  21.0
# 204          GB         50.0  23.0
# 48          PIT         52.0  21.0
# 96          CLE         74.0  23.0
# 227          GB         85.0  21.0
# 252         CLE         99.0  21.0
# 171          LV        100.0  22.0
# 162         DET        112.0  21.0
# 250         LAC        125.0  22.0
# 182         MIA        125.0  22.0
#
# [28 rows x 53 columns]

# %%
df_players: pd.DataFrame = df_with_stats[['player_name', 'headshot_url_x', 'cluster', 'draft_number']]

df_players.sort_values(by = ['cluster', 'draft_number'], inplace = True)

df_players
# Out:
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\1893164730.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             player_name                                     headshot_url_x  \
# 17        Ja'Marr Chase  https://static.www.nfl.com/image/private/f_aut...
# 28         Malik Nabers  https://static.www.nfl.com/image/upload/f_auto...
# 3           Rome Odunze  https://static.www.nfl.com/image/upload/f_auto...
# 221       Treylon Burks  https://static.www.nfl.com/image/private/f_aut...
# 89     Quentin Johnston  https://static.www.nfl.com/image/private/f_aut...
# 16     Brian Thomas Jr.  https://static.www.nfl.com/image/upload/f_auto...
# 4        Ricky Pearsall  https://static.www.nfl.com/image/upload/f_auto...
# 204         Jayden Reed  https://static.www.nfl.com/image/private/f_aut...
# 227       Amari Rodgers  https://static.www.nfl.com/image/private/f_aut...
# 252          David Bell  https://static.www.nfl.com/image/private/f_aut...
# 171          Tre Tucker  https://static.www.nfl.com/image/private/f_aut...
# 162   Amon-Ra St. Brown  https://static.www.nfl.com/image/private/f_aut...
# 250        Derius Davis  https://static.www.nfl.com/image/private/f_aut...
# 182       Erik Ezukanma  https://static.www.nfl.com/image/private/f_aut...
# 124  Jaxon Smith-Njigba  https://static.www.nfl.com/image/private/f_aut...
# 128      Rashod Bateman  https://static.www.nfl.com/image/private/f_aut...
# 137        Keon Coleman  https://static.www.nfl.com/image/upload/f_auto...
# 11       Jonathan Mingo  https://static.www.nfl.com/image/private/f_aut...
# 44        Rondale Moore  https://static.www.nfl.com/image/private/f_aut...
# 48       George Pickens  https://static.www.nfl.com/image/private/f_aut...
# 96       Cedric Tillman                                               None
# 146      Garrett Wilson  https://static.www.nfl.com/image/private/f_aut...
# 104         Chris Olave  https://static.www.nfl.com/image/private/f_aut...
# 207        Jahan Dotson  https://static.www.nfl.com/image/private/f_aut...
# 65       Kadarius Toney  https://static.www.nfl.com/image/private/f_aut...
# 126         Zay Flowers  https://static.www.nfl.com/image/private/f_aut...
# 219      Jordan Addison  https://static.www.nfl.com/image/private/f_aut...
# 43        Xavier Worthy  https://static.www.nfl.com/image/upload/f_auto...
#
#      cluster  draft_number
# 17         0           5.0
# 28         0           6.0
# 3          0           9.0
# 221        0          18.0
# 89         0          21.0
# 16         0          23.0
# 4          0          31.0
# 204        1          50.0
# 227        1          85.0
# 252        1          99.0
# 171        1         100.0
# 162        1         112.0
# 250        1         125.0
# 182        1         125.0
# 124        2          20.0
# 128        2          27.0
# 137        2          33.0
# 11         2          39.0
# 44         2          49.0
# 48         2          52.0
# 96         2          74.0
# 146        3          10.0
# 104        3          11.0
# 207        3          16.0
# 65         3          20.0
# 126        3          22.0
# 219        3          23.0
# 43         3          28.0

# %%
df_final: pd.DataFrame = (
    pd.merge(
    left = df, 
    right = nfl_data, 
    how = 'left', 
    on = 'player_name'
)
    .drop_duplicates(subset = ['player_name'], keep = 'first')
    .sort_values(by = 'draft_number')
    .groupby('cluster').mean().round(2)
)

df_final = df_final[['height_x', 'weight_x', 'forty', 'RAS', 'draft_number']].reset_index()

df_final
# Out:
# C:\Users\ernie\AppData\Local\Temp\ipykernel_37164\1477774670.py:10: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#    cluster  height_x  weight_x  forty   RAS  draft_number
# 0        0     73.28    199.26   4.44  8.85        100.42
# 1        1     70.94    192.36   4.52  5.50        164.77
# 2        2     73.75    206.41   4.47  8.65        138.62
# 3        3     70.16    182.74   4.43  7.65        101.96

# %%
clusters_overview: GT = (
    GT(df_final)
    .tab_header(
        title = md('Wide Receiver Cluster Breakdown: Physical Characteristics'),
        subtitle = md('*All Metrics are the average among all the players in that cluster*')
    )
    .tab_options(
        table_font_names=system_fonts("industrial")
    )
    .cols_label(
        cluster = 'Cluster',
        height_x = 'Height',
        weight_x = 'Weight',
        forty = 'Forty Time',
        draft_number = 'Draft Position'
    )
    .data_color(
        columns = ['height_x', 'weight_x', 'RAS'],
        palette = 'BuPu',
    )
    .data_color(
        columns = ['draft_number', 'forty'],
        reverse = True,
        palette = 'BuPu'
    )
)

# clusters_overview.save(file = '../img/wide_receiver_cluster_overview.png', scale = 6, web_driver = 'firefox')

# %% [markdown]
# ![Wide Receiver Cluster Overview](../img/wide_receiver_cluster_overview.png)

# %%
df_25_final: pd.DataFrame = df_25_prospects.sort_values(by = 'RAS', ascending = False).groupby('cluster').head(7).sort_values(by = 'cluster').reset_index()

df_25_final = df_25_final[['player_name', 'RAS', 'cluster']]

df_25_final
# Out:
#          player_name   RAS  cluster
# 0       Isaiah Neyor  9.90        0
# 1       Emeka Egbuka  9.72        0
# 2       Chimere Dike  9.72        0
# 3      Elic Ayomanor  9.71        0
# 4     Jayden Higgins  9.63        0
# 5          Jack Bech  9.51        0
# 6     Elijhah Badger  9.32        0
# 7         Josh Kelly  3.98        1
# 8        Isaiah Bond  4.23        1
# 9    Traeshon Holden  5.42        1
# 10  Konata Mumpfield  6.35        1
# 11    Dominic Lovett  6.67        1
# 12    Jacolby George  3.75        1
# 13       Kobe Hudson  3.94        1
# 14     Kaden Prather  7.68        2
# 15     Beaux Collins  9.09        2
# 16       Jaylin Lane  9.56        2
# 17       Tory Horton  9.83        2
# 18    Da'Quan Felton  8.30        2
# 19       Tez Johnson  7.31        3
# 20    Daniel Jackson  7.14        3
# 21        Tai Felton  9.20        3
# 22       Jaylin Noel  9.75        3
# 23   Ja'Corey Brooks  4.15        3
# 24   Xavier Restrepo  3.96        3

# %%
clusters_25_overview: GT = (
    GT(df_25_final)
    .tab_header(
        title = md('2025 Wide Receiver Draft Prospect Cluster Breakdown'),
        subtitle = md('*RAS Scores and the Classified Cluster for a Subset of the Incoming Draft Class*')
    )
    .tab_options(
        table_font_names=system_fonts("industrial")
    )
    .cols_label(
        cluster = 'Cluster',
        player_name = 'Name',
    )
    .data_color(
        columns = ['RAS'],
        palette = 'BuPu',
    )
)

# clusters_25_overview.save('../img/wide_receiver_25_clusters.png', scale = 2, web_driver = 'firefox')

# %% [markdown]
# ![2025 Draft Class Clusters](../img/wide_receiver_25_clusters.png?12)

# %%
from sklearn.metrics.pairwise import euclidean_distances

amon = df_scaled.loc[df_scaled['player_name'] == 'Amon-Ra St. Brown'].iloc[:, 2:].to_numpy()
ja = df_scaled.loc[df_scaled['player_name'] == 'Jordan Addison'].iloc[:, 2:].to_numpy()
euclidean_distances(df_scaled.loc[df_scaled['player_name'] == 'Rondale Moore'].iloc[:, 2:].to_numpy(), df_scaled.loc[df_scaled['player_name'] == 'Jaxon Smith-Njigba'].iloc[:, 2:].to_numpy())
# Out:
# array([[4.84692861]])

# %%
euclidean_distances(df_25_prospects.loc[df_25_prospects['player_name'] == 'Emeka Egbuka'].iloc[:, 2:13].to_numpy(), df_scaled.loc[df_scaled['player_name'] == 'Jaxon Smith-Njigba'].iloc[:, 2:].to_numpy())
# Out:
# array([[1036.17366042]])
